# %% [markdown]
# # Imports

# %%
import sys 
sys.path.append("/home/jovyan/work/notebooks/satellite_data/SA_segmentation/")
import sys 
sys.path.append("/home/jovyan/work/notebooks/satellite_data/SA_segmentation/segmentation_models.pytorch")
import segmentation_models_pytorch as smp
import rasterio
from rasterio.plot import show
from rasterio.mask import mask
from rasterio.windows import from_bounds
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
import numpy as np
from patchify import patchify
import torch
from torch.nn import DataParallel
from torch.functional import F
from torch import nn
from torch.utils.data import DataLoader
from shapely.geometry import box
from torchvision import transforms
import time
import random

from pytorch_segmentation.data.train_dataset import TrainDataset
from pytorch_segmentation.data.inmemory_dataset import InMemorySatDataset
from pytorch_segmentation.train_net import train_smp
from pytorch_segmentation.models import UNet
from pytorch_segmentation.losses.dice import DiceLoss
from pytorch_segmentation.losses.tversky import TverskyLoss
from pytorch_segmentation.losses.dice_V2 import FocalTversky_loss
import pytorch_segmentation.augmentation.transforms as seg_transforms
from pytorch_segmentation.losses.bce_pixel_weights import CrossEntropyWithPixelWeights

seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# %%
cfg = {
    #SA high resoluted data
    "shape_path_sa": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V31/data_pool/SA_tree_shapes/labels.geojson",
    "train_data_path_sa": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V31/train/SA",
    # "val_data_path_sa": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V30/val/SA",
    # "test_data_path_sa": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V30/test/SA",
    
    
    #Rwanda data 2008
    "shape_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V31/data_pool/rwanda_tree_shapes/Training_Data_Rwanda_high_res.geojson",
    "train_data_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V31/train/rwanda_2008",
    # "val_data_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V30/val/rwanda_2008",
    # "test_data_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V30/test/rwanda_2008",
    
    #Rwanda data 2019
    "shape_path_rw_2019": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V31/data_pool/rwanda_tree_shapes/Training_Data_Rwanda_low_res.geojson",
    "train_data_path_rw_2019": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V31/train/rwanda_2019",
    # "val_data_path_rw_2019": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V30/val/rwanda_2019",
    # "test_data_path_rw_2019": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V30/test/rwanda_2019",

    "tensorboard_path": "/home/jovyan/work/notebooks/runs",

    # patch_size = [364,364,3]# [x,y,bands]
    # overlap = 300

    # patch_size = [321,321,3]# [x,y,bands]
    # overlap = 270


    "patch_size": [300,300],# [x,y,bands]
    "overlap": 150,

#     "val_patch_size": [256,256],# [x,y,bands]
#     "val_overlap": 200,

#     "test_patch_size": [256,256],
#     "overlap_test": 128,

    "padding": False,#True

    "epochs": 2000,#25

    "early_stopping": 25,

    "dropout": True,

    "scheduler": False,
    "scheduler_warmup": 20,#10
    "sched_step": 15,
    "sched_gamma": 0.1,

    #batch_size = 200
    #batch_size = 50
    "batch_size": 65,#110, #50 #150 #75

    "lr": 3e-4, #1e-3,
    "weight_decay": 1e-4, #1e-3,

    "weighted": False,
    "weight": 0.4, #0.1
    "sampler_replacement": True,

    "metric": "rmse_cov",

    "n_channels": 3,

    "nworkers": 15,
    "pin_memory": True,

    "nimgs": 7,
    "figsize": (24,21),
    
    "train_size":0.75,
    
    "fp16":True,
    "loss_fn": nn.BCEWithLogitsLoss(),#nn.CrossEntropyLoss()#weight=torch.Tensor([0.25,4.]).to(torch.device("cuda:1"))) #TverskyLoss(0.3,0.7) 
}

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

save_dir = "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/saved_models"




transform_sa_high = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    seg_transforms.RandomApply([
        seg_transforms.Pad(100),
        seg_transforms.RandomRotation(360),
        seg_transforms.CenterCrop(282),
        seg_transforms.RandomResizeCrop((256,256),scale=(0.8,1.2)), #scale=(0.5,1)
        #seg_transforms.Add_VDVI(),
        seg_transforms.ColorJitter(brightness=(0.9,1.3),contrast=(0.9,1.3),saturation=0.2),
        
        #seg_transforms.ColorJitter(brightness=0.2,contrast=0.2,saturation=0.2),
        #seg_transforms.RandomPixel(ratio=0.005,random_apply=0.2)]
    ]
    ,p=1),
    seg_transforms.CenterCrop(256)
])


transform_rw_2008 = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    seg_transforms.RandomApply([
        seg_transforms.Pad(100),
        seg_transforms.RandomRotation(360),
        seg_transforms.CenterCrop(282),
        seg_transforms.RandomResizeCrop((256,256),scale=(0.8,1.2)), #scale=(0.5,1)
        #seg_transforms.Add_VDVI(),
        seg_transforms.ColorJitter(brightness=(0.9,1.3),contrast=(0.9,1.3),saturation=0.2),
        #seg_transforms.ColorJitter(brightness=0.2,contrast=0.2,saturation=0.2),
        #seg_transforms.RandomPixel(ratio=0.005,random_apply=0.2)]
    ]
    ,p=1),
    seg_transforms.CenterCrop(256)
])


transform_rw_2019 = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    seg_transforms.RandomApply([
        seg_transforms.Pad(100),
        seg_transforms.RandomRotation(360),
        seg_transforms.CenterCrop(282),
        seg_transforms.RandomResizeCrop((256,256),scale=(1,1.3)), #scale=(1,1)
        #seg_transforms.Add_VDVI(),
        #seg_transforms.ColorJitter(brightness=(0.9,1.3),contrast=(0.9,1.3),saturation=0.2),
        #seg_transforms.ColorJitter(brightness=0.2,contrast=0.2,saturation=0.2),
        #seg_transforms.RandomPixel(ratio=0.005,random_apply=0.2)]
    ]
    ,p=1),
    seg_transforms.CenterCrop(256)
])


#val_transform= None

val_transform = seg_transforms.Compose([
    #seg_transforms.Resize(320),
    seg_transforms.CenterCrop(256),
])

# %% [markdown]
# # 1.1 Data Collection

# %% [markdown]
# #### Create Training and Test Dataset - SA

# %%
dataset_sa = TrainDataset(dataset_path=None,data_file_path=cfg["train_data_path_sa"],
                   shape_path=cfg["shape_path_sa"],#tree_size_threshold=cfg["tree_size_threshold_sa_high"],
                             overlap=cfg["overlap"],patch_size=cfg["patch_size"],padding=cfg["padding"])

# train_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_train,
#                              overlap=overlap,patch_size=patch_size,padding=padding,transform=transform)
# val_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_val,
#                              overlap=val_overlap,patch_size=val_patch_size,padding=padding,transform=val_transform)
# # test_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_test,
#                              overlap=overlap_test,patch_size=test_patch_size,padding=padding,transform=test_transform)


print("Len Train: ",len(dataset_sa))
#print("Len Test: ",len(test_dataset_sa))
# Out:
# 100%|██████████| 201/201 [00:24<00:00,  8.16it/s]
# Len Train:  6281

# %%
dataset_sa.show_tuple(100)

# %%
dataset_sa.show_tuple(100,transform=False)

# %% [markdown]
# #### Create Training and Test Dataset - Rwanda 2008

# %%
dataset_rw_2008 = TrainDataset(dataset_path=None,data_file_path=cfg["train_data_path_rw_2008"],
                   shape_path=cfg["shape_path_rw_2008"],#tree_size_threshold=cfg["tree_size_threshold_rw_2008"],
                             overlap=cfg["overlap"],patch_size=cfg["patch_size"],padding=cfg["padding"])
# test_dataset_rw = RwandaDataset(dataset_path=None,data_file_path=test_data_path_rw,
#                    shape_path=shape_path_rw, overlap=overlap_test,patch_size=test_patch_size,padding=padding,transform=test_transform)

print("Len Train: ",len(dataset_rw_2008))
#print("Len Test: ",len(test_dataset_rw))
# Out:
# 100%|██████████| 100/100 [00:36<00:00,  2.74it/s]
# Len Train:  4245

# %%
dataset_rw_2008.show_tuple(500)

# %%
dataset_rw_2008.show_tuple(500,transform=False)

# %% [markdown]
# #### Create Training and Test Dataset - Rwanda 2019

# %%
dataset_rw_2019 = TrainDataset(dataset_path=None,data_file_path=cfg["train_data_path_rw_2019"],
                   shape_path=cfg["shape_path_rw_2019"],#tree_size_threshold=cfg["tree_size_threshold_rw_2019"],
                             overlap=cfg["overlap"],patch_size=cfg["patch_size"],padding=cfg["padding"])
# test_dataset_rw = RwandaDataset(dataset_path=None,data_file_path=test_data_path_rw,
#                    shape_path=shape_path_rw, overlap=overlap_test,patch_size=test_patch_size,padding=padding,transform=test_transform)

print("Len Train: ",len(dataset_rw_2019))
#print("Len Test: ",len(test_dataset_rw))
# Out:
#  32%|███▏      | 29/90 [00:12<00:23,  2.64it/s]
# Shape /home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V31/train/rwanda_2019/image_370_19.tif is too small for patch size with size: (3, 216, 602)
#  54%|█████▍    | 49/90 [00:22<00:14,  2.81it/s]
# Shape /home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V31/train/rwanda_2019/image_410_19.tif is too small for patch size with size: (3, 296, 885)
#  82%|████████▏ | 74/90 [00:35<00:08,  1.93it/s]
# Shape /home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V31/train/rwanda_2019/image_29_4ESE1R.tif.tif is too small for patch size with size: (3, 258, 451)
#  89%|████████▉ | 80/90 [00:37<00:04,  2.50it/s]
# Shape /home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V31/train/rwanda_2019/image_367_19.tif is too small for patch size with size: (3, 294, 468)
# 100%|██████████| 90/90 [00:43<00:00,  2.06it/s]
# Len Train:  2903

# %%
dataset_rw_2019.show_tuple(500)

# %%
dataset_rw_2019.show_tuple(500,transform=False)

# %% [markdown]
# # 2. Model Training

# %%
from torch.utils.data import random_split
from  pytorch_segmentation.data.apply_transform import ApplyTransform
train_datasets = []
val_datasets = []
train_transform = [transform_sa_high,transform_rw_2008,transform_rw_2019]

for i,d in enumerate([dataset_sa,dataset_rw_2008,dataset_rw_2019]):
    train_size = int(cfg["train_size"] * len(d))
    val_size = len(d) - train_size
    train_dataset, val_dataset = random_split(d, [train_size, val_size])
    train_dataset = ApplyTransform(train_dataset,train_transform[i])
    val_dataset =  ApplyTransform(val_dataset,val_transform)
    train_datasets.append(train_dataset)
    val_datasets.append(val_dataset)

# %%
from pytorch_segmentation.utils.sampling import create_weighted_dataset
from pytorch_segmentation.data.concat_dataset import ConcatDataset

if cfg["weighted"]:
    train_dataset,weights = create_weighted_dataset(train_datasets,weight=cfg["weight"])
    sampler = torch.utils.data.sampler.WeightedRandomSampler(weights, len(weights),replacement=cfg["sampler_replacement"]) 
else:
    train_dataset = ConcatDataset(train_datasets,shuffle=True)



val_dataset = ConcatDataset(val_datasets,shuffle=True)
#test_dataset = torch.utils.data.ConcatDataset([test_dataset_rw, test_dataset_sa])

# %%
if cfg["weighted"]:
    train_dl =DataLoader(train_dataset,sampler=sampler,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],shuffle=False,pin_memory=cfg["pin_memory"],
                      drop_last=True)
else:
    train_dl =DataLoader(train_dataset,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],shuffle=True,pin_memory=cfg["pin_memory"],
                  drop_last=True)

if (len(val_dataset) % cfg["batch_size"]) < cfg["nimgs"]:
    val_dl = DataLoader(val_dataset,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],
                     shuffle=False,pin_memory=cfg["pin_memory"],drop_last=True)
else:
    val_dl = DataLoader(val_dataset,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],
                         shuffle=False,pin_memory=cfg["pin_memory"],drop_last=False)
# test_dl = DataLoader(test_dataset,batch_size=batch_size,num_workers=nworkers,
#                      shuffle=False,pin_memory=pin_memory,drop_last=False)

# %% [markdown]
# ## 2.2 Advanced Unet
# https://github.com/milesial/Pytorch-UNet

# %%
model_path = save_dir+"/smp_unet_mitb5_"+str(time.strftime("%d_%m_%Y_%H%M%S"))
net = smp.Unet(
    encoder_name="mit_b5",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=3,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=1,                      # model output channels (number of classes in your dataset)
)

net= DataParallel(net,device_ids=[0])

net = net.to(device=device)

# %%
opt = torch.optim.Adam(net.parameters(),lr=cfg["lr"])
#opt = torch.optim.Adam(net.parameters(),lr=lr,weight_decay=weight_decay)
if cfg["scheduler"]:
    scheduler = torch.optim.lr_scheduler.StepLR(opt, cfg["sched_step"],gamma=cfg["sched_gamma"]) #ReduceLROnPlateau(opt, 'max', patience=2) #S
else: 
    scheduler = None

# %%
train_loss,valid_loss = train_smp(net,train_dl,val_dl,cfg["loss_fn"],opt,cfg["epochs"],model_path=model_path+".pth",scheduler=scheduler,
                              scheduler_warmup=cfg["scheduler_warmup"],early_stopping=cfg["early_stopping"],fp16=cfg["fp16"],
                              metric=cfg["metric"],tensorboard_path=cfg["tensorboard_path"],nimgs=cfg["nimgs"],figsize=cfg["figsize"],cfg=cfg,device=device,seed=seed)
# Out:
# INFO: Start run for smp_unet_mitb5_10_03_2023_091535!
# Epoch 0/1999
# ----------
# train Loss: 0.3068 rmse_cov: 0.07483954799602913
# valid Loss: 0.1858 rmse_cov: 0.04327597000241617
# Epoch 1/1999
# ----------
# train Loss: 0.1608 rmse_cov: 0.03507383435579847
# valid Loss: 0.1501 rmse_cov: 0.030097641143421044
# Epoch 2/1999
# ----------
# train Loss: 0.1368 rmse_cov: 0.02985136763330516
# valid Loss: 0.1222 rmse_cov: 0.026786924528091675
# Epoch 3/1999
# ----------
# train Loss: 0.1224 rmse_cov: 0.024770725789445693
# valid Loss: 0.1214 rmse_cov: 0.03351559168258507
# Epoch 4/1999
# ----------
# train Loss: 0.1193 rmse_cov: 0.024461608682967196
# valid Loss: 0.1135 rmse_cov: 0.02096124702161242
# Epoch 5/1999
# ----------
# train Loss: 0.1157 rmse_cov: 0.023481404973432613
# valid Loss: 0.1083 rmse_cov: 0.023422363660863626
# Epoch 6/1999
# ----------
# train Loss: 0.1083 rmse_cov: 0.02063543023657176
# valid Loss: 0.1026 rmse_cov: 0.0185187959141894
# Epoch 7/1999
# ----------
# train Loss: 0.1069 rmse_cov: 0.019788281003414638
# valid Loss: 0.1024 rmse_cov: 0.01709068418669271
# Epoch 8/1999
# ----------
# train Loss: 0.1009 rmse_cov: 0.017390087300304845
# valid Loss: 0.0976 rmse_cov: 0.014655810263591237
# Epoch 9/1999
# ----------
# train Loss: 0.0996 rmse_cov: 0.01665236352195606
# valid Loss: 0.0970 rmse_cov: 0.015230501957717938
# Epoch 10/1999
# ----------
# train Loss: 0.0980 rmse_cov: 0.016011194374075652
# valid Loss: 0.0996 rmse_cov: 0.017472708028422053
# Epoch 11/1999
# ----------
# train Loss: 0.0977 rmse_cov: 0.016358941669512055
# valid Loss: 0.0954 rmse_cov: 0.017515359105928805
# Epoch 12/1999
# ----------
# train Loss: 0.1044 rmse_cov: 0.019515980570785175
# valid Loss: 0.0974 rmse_cov: 0.015802481720774666
# Epoch 14/1999
# ----------
# train Loss: 0.0967 rmse_cov: 0.015792081461546068
# valid Loss: 0.0937 rmse_cov: 0.01479120413839582
# Epoch 15/1999
# ----------
# train Loss: 0.0934 rmse_cov: 0.014438776875306902
# valid Loss: 0.0925 rmse_cov: 0.013063208823322132
# Epoch 16/1999
# ----------
# train Loss: 0.0960 rmse_cov: 0.015683377364626324
# valid Loss: 0.0995 rmse_cov: 0.018195276981789146
# Epoch 17/1999
# ----------
# train Loss: 0.1019 rmse_cov: 0.018451218722182833
# valid Loss: 0.0932 rmse_cov: 0.013626975391778777
# Epoch 18/1999
# ----------
# train Loss: 0.0933 rmse_cov: 0.014729756014301352
# valid Loss: 0.0943 rmse_cov: 0.01689274237641189
# Epoch 19/1999
# ----------
# train Loss: 0.0922 rmse_cov: 0.014201964126611285
# valid Loss: 0.0911 rmse_cov: 0.012567336800258387
# Epoch 20/1999
# ----------
# train Loss: 0.0923 rmse_cov: 0.014378590327331495
# valid Loss: 0.0926 rmse_cov: 0.0147498114624824
# Epoch 21/1999
# ----------
# train Loss: 0.0989 rmse_cov: 0.017619873770922348
# valid Loss: 0.0955 rmse_cov: 0.018941880896383628
# Epoch 22/1999
# ----------
# train Loss: 0.0951 rmse_cov: 0.015503106970809836
# valid Loss: 0.0921 rmse_cov: 0.015274106914853501
# Epoch 23/1999
# ----------
# train Loss: 0.0893 rmse_cov: 0.012767539462518565
# valid Loss: 0.0912 rmse_cov: 0.01728664984276125
# Epoch 24/1999
# ----------
# train Loss: 0.0876 rmse_cov: 0.011773502815546249
# valid Loss: 0.0886 rmse_cov: 0.012788700470526186
# Epoch 25/1999
# ----------
# train Loss: 0.0872 rmse_cov: 0.012096381535829445
# valid Loss: 0.0887 rmse_cov: 0.012783635382594036
# Epoch 26/1999
# ----------
# train Loss: 0.0864 rmse_cov: 0.011738543934628086
# valid Loss: 0.0891 rmse_cov: 0.012939094275931503
# Epoch 27/1999
# ----------
# train Loss: 0.0859 rmse_cov: 0.011716495232440184
# valid Loss: 0.0862 rmse_cov: 0.012208198736044411
# Epoch 28/1999
# ----------
# train Loss: 0.0844 rmse_cov: 0.011045972224049337
# valid Loss: 0.0859 rmse_cov: 0.011747400522987317
# Epoch 29/1999
# ----------
# train Loss: 0.0837 rmse_cov: 0.010555230217958988
# valid Loss: 0.0856 rmse_cov: 0.01124430568245536
# Epoch 30/1999
# ----------
# train Loss: 0.0881 rmse_cov: 0.012921374415573705
# valid Loss: 0.0873 rmse_cov: 0.013905453911158177
# Epoch 31/1999
# ----------
# train Loss: 0.0872 rmse_cov: 0.012576551545391002
# valid Loss: 0.0875 rmse_cov: 0.012093369451571332
# Epoch 32/1999
# ----------
# train Loss: 0.0835 rmse_cov: 0.01085934377124657
# valid Loss: 0.0850 rmse_cov: 0.011273060699059215
# Epoch 33/1999
# ----------
# train Loss: 0.0822 rmse_cov: 0.010028885308211038
# valid Loss: 0.0849 rmse_cov: 0.012151519988501851
# Epoch 34/1999
# ----------
# train Loss: 0.0810 rmse_cov: 0.009827520825938057
# valid Loss: 0.0838 rmse_cov: 0.011341255080275378
# Epoch 35/1999
# ----------
# train Loss: 0.0799 rmse_cov: 0.009664342676838739
# valid Loss: 0.0842 rmse_cov: 0.010241854623548995
# Epoch 36/1999
# ----------
# train Loss: 0.0794 rmse_cov: 0.00929656649603071
# valid Loss: 0.0829 rmse_cov: 0.010171993010646621
# Epoch 37/1999
# ----------
# train Loss: 0.0789 rmse_cov: 0.009256279951029909
# valid Loss: 0.0843 rmse_cov: 0.009801416620573327
# Epoch 38/1999
# ----------
# train Loss: 0.0783 rmse_cov: 0.009079959868733672
# valid Loss: 0.0820 rmse_cov: 0.00986002598400914
# Epoch 39/1999
# ----------
# train Loss: 0.0771 rmse_cov: 0.00870628167307254
# valid Loss: 0.0820 rmse_cov: 0.01075963583564423
# Epoch 40/1999
# ----------
# train Loss: 0.0765 rmse_cov: 0.00861371974583323
# valid Loss: 0.0814 rmse_cov: 0.00897159111658602
# Epoch 41/1999
# ----------
# train Loss: 0.0759 rmse_cov: 0.008429736937229756
# valid Loss: 0.0816 rmse_cov: 0.009534331025424309
# Epoch 42/1999
# ----------
# train Loss: 0.0757 rmse_cov: 0.008476201260356971
# valid Loss: 0.0807 rmse_cov: 0.008003605069827158
# Epoch 43/1999
# ----------
# train Loss: 0.0756 rmse_cov: 0.008617550410148101
# valid Loss: 0.0806 rmse_cov: 0.009694182600806062
# Epoch 44/1999
# ----------
# train Loss: 0.0748 rmse_cov: 0.008252304671850156
# valid Loss: 0.0807 rmse_cov: 0.00994306572733198
# Epoch 45/1999
# ----------
# train Loss: 0.0745 rmse_cov: 0.007939876822057405
# valid Loss: 0.0798 rmse_cov: 0.009315915487819784
# Epoch 46/1999
# ----------
# train Loss: 0.0731 rmse_cov: 0.007667959725776504
# valid Loss: 0.0788 rmse_cov: 0.008975434146547565
# Epoch 47/1999
# ----------
# train Loss: 0.0721 rmse_cov: 0.007449695392851205
# valid Loss: 0.0781 rmse_cov: 0.008015506843315123
# Epoch 48/1999
# ----------
# train Loss: 0.0716 rmse_cov: 0.007298992516342532
# valid Loss: 0.0776 rmse_cov: 0.009396974660703498
# Epoch 49/1999
# ----------
# train Loss: 0.0706 rmse_cov: 0.007141343610987341
# valid Loss: 0.0773 rmse_cov: 0.008032105776172738
# Epoch 50/1999
# ----------
# train Loss: 0.0702 rmse_cov: 0.007045989050465158
# valid Loss: 0.0777 rmse_cov: 0.010088962325884512
# Epoch 51/1999
# ----------
# train Loss: 0.0696 rmse_cov: 0.006938756291653735
# valid Loss: 0.0774 rmse_cov: 0.009078311716572635
# Epoch 52/1999
# ----------
# train Loss: 0.0689 rmse_cov: 0.006632625873204295
# valid Loss: 0.0764 rmse_cov: 0.008325170765093844
# Epoch 53/1999
# ----------
# train Loss: 0.0682 rmse_cov: 0.006583581078226947
# valid Loss: 0.0766 rmse_cov: 0.008568212079412704
# Epoch 54/1999
# ----------
# train Loss: 0.0685 rmse_cov: 0.006904768750007711
# valid Loss: 0.0773 rmse_cov: 0.008620593448406034
# Epoch 55/1999
# ----------
# train Loss: 0.0685 rmse_cov: 0.006899960760453526
# valid Loss: 0.0772 rmse_cov: 0.009201276932470666
# Epoch 56/1999
# ----------
# train Loss: 0.0671 rmse_cov: 0.006402804585388291
# valid Loss: 0.0752 rmse_cov: 0.008434771474874482
# Epoch 57/1999
# ----------
# train Loss: 0.0661 rmse_cov: 0.006360922442738045
# valid Loss: 0.0752 rmse_cov: 0.006898803329086926
# Epoch 58/1999
# ----------
# train Loss: 0.0658 rmse_cov: 0.006033158522490468
# valid Loss: 0.0754 rmse_cov: 0.008324761966331555
# Epoch 59/1999
# ----------
# train Loss: 0.0652 rmse_cov: 0.006064661028110556
# valid Loss: 0.0752 rmse_cov: 0.007200481304588325
# Epoch 60/1999
# ----------
# train Loss: 0.0646 rmse_cov: 0.006007486775720006
# valid Loss: 0.0756 rmse_cov: 0.00882913784896686
# Epoch 61/1999
# ----------
# train Loss: 0.0646 rmse_cov: 0.006225788964665206
# valid Loss: 0.0743 rmse_cov: 0.007246552961475063
# Epoch 62/1999
# ----------
# train Loss: 0.0636 rmse_cov: 0.005915227919065994
# valid Loss: 0.0733 rmse_cov: 0.007751083247702936
# Epoch 63/1999
# ----------
# train Loss: 0.0631 rmse_cov: 0.0056637063956113815
# valid Loss: 0.0734 rmse_cov: 0.008220557927482006
# Epoch 64/1999
# ----------
# train Loss: 0.0630 rmse_cov: 0.005571879440841802
# valid Loss: 0.0738 rmse_cov: 0.008643461239113007
# Epoch 65/1999
# ----------
# train Loss: 0.0626 rmse_cov: 0.005316904586170594
# valid Loss: 0.0736 rmse_cov: 0.00793520175925633
# Epoch 66/1999
# ----------
# train Loss: 0.0904 rmse_cov: 0.015231224750339719
# valid Loss: 0.1098 rmse_cov: 0.020449521105035576
# Epoch 67/1999
# ----------
# train Loss: 0.0846 rmse_cov: 0.013063646394707626
# valid Loss: 0.0784 rmse_cov: 0.009444409075971381
# Epoch 68/1999
# ----------
# train Loss: 0.0676 rmse_cov: 0.006999671717924404
# valid Loss: 0.0749 rmse_cov: 0.008479348579036245
# Epoch 69/1999
# ----------
# train Loss: 0.0638 rmse_cov: 0.005725585573869402
# valid Loss: 0.0738 rmse_cov: 0.008021525885251577
# Epoch 70/1999
# ----------
# train Loss: 0.0623 rmse_cov: 0.005266715744820117
# valid Loss: 0.0724 rmse_cov: 0.006742204260413767
# Epoch 71/1999
# ----------
# train Loss: 0.0611 rmse_cov: 0.005026320859909154
# valid Loss: 0.0720 rmse_cov: 0.007115874235898403
# Epoch 72/1999
# ----------
# train Loss: 0.0605 rmse_cov: 0.005221707627312266
# valid Loss: 0.0723 rmse_cov: 0.007620522721281569
# Epoch 73/1999
# ----------
# train Loss: 0.0601 rmse_cov: 0.005073898894547706
# valid Loss: 0.0722 rmse_cov: 0.007636594657746542
# Epoch 74/1999
# ----------
# train Loss: 0.0594 rmse_cov: 0.004845082230265729
# valid Loss: 0.0713 rmse_cov: 0.007073059702060848
# Epoch 75/1999
# ----------
# train Loss: 0.0588 rmse_cov: 0.0046864074822274785
# valid Loss: 0.0712 rmse_cov: 0.006351522042050882
# Epoch 76/1999
# ----------
# train Loss: 0.0586 rmse_cov: 0.004745987968684878
# valid Loss: 0.0716 rmse_cov: 0.006652695748591244
# Epoch 77/1999
# ----------
# train Loss: 0.0582 rmse_cov: 0.004728078991872959
# valid Loss: 0.0710 rmse_cov: 0.006853599314658006
# Epoch 78/1999
# ----------
# train Loss: 0.0579 rmse_cov: 0.004776399477307298
# valid Loss: 0.0711 rmse_cov: 0.006417058982192388
# Epoch 79/1999
# ----------
# train Loss: 0.0575 rmse_cov: 0.004555421309301014
# valid Loss: 0.0708 rmse_cov: 0.0077473265124442196
# Epoch 80/1999
# ----------
# train Loss: 0.0572 rmse_cov: 0.004623781300953089
# valid Loss: 0.0714 rmse_cov: 0.0071217297641108495
# Epoch 81/1999
# ----------
# train Loss: 0.0569 rmse_cov: 0.004626626966328313
# valid Loss: 0.0701 rmse_cov: 0.006324547739925729
# Epoch 82/1999
# ----------
# train Loss: 0.0567 rmse_cov: 0.0045605853587007954
# valid Loss: 0.0698 rmse_cov: 0.00621477900148902
# Epoch 83/1999
# ----------
# train Loss: 0.0562 rmse_cov: 0.004465879358861284
# valid Loss: 0.0699 rmse_cov: 0.006471734374471011
# Epoch 84/1999
# ----------
# train Loss: 0.0616 rmse_cov: 0.005964759162170747
# valid Loss: 0.0731 rmse_cov: 0.006755378015226252
# Epoch 85/1999
# ----------
# train Loss: 0.0575 rmse_cov: 0.00471051546458068
# valid Loss: 0.0707 rmse_cov: 0.007035355650228993
# Epoch 86/1999
# ----------
# train Loss: 0.0560 rmse_cov: 0.004404021403509494
# valid Loss: 0.0710 rmse_cov: 0.007415962318719835
# Epoch 87/1999
# ----------
# train Loss: 0.0553 rmse_cov: 0.004478492455979182
# valid Loss: 0.0701 rmse_cov: 0.006932473521811062
# Epoch 88/1999
# ----------
# train Loss: 0.0549 rmse_cov: 0.0042441965727844895
# valid Loss: 0.0698 rmse_cov: 0.0067413003044854486
# Epoch 89/1999
# ----------
# train Loss: 0.0546 rmse_cov: 0.004313814244996072
# valid Loss: 0.0701 rmse_cov: 0.006713549208284715
# Epoch 90/1999
# ----------
# train Loss: 0.0544 rmse_cov: 0.00416472509762091
# valid Loss: 0.0694 rmse_cov: 0.007022154689582088
# Epoch 91/1999
# ----------
# train Loss: 0.0542 rmse_cov: 0.004234720058595834
# valid Loss: 0.0686 rmse_cov: 0.005850516820501677
# Epoch 92/1999
# ----------
# train Loss: 0.0534 rmse_cov: 0.004048130969952074
# valid Loss: 0.0684 rmse_cov: 0.005977465943248965
# Epoch 93/1999
# ----------
# train Loss: 0.0536 rmse_cov: 0.004377075326534186
# valid Loss: 0.0689 rmse_cov: 0.006451923886827524
# Epoch 94/1999
# ----------
# train Loss: 0.0533 rmse_cov: 0.004048485545704627
# valid Loss: 0.0694 rmse_cov: 0.0063688386983456365
# Epoch 95/1999
# ----------
# train Loss: 0.0529 rmse_cov: 0.004013053949216201
# valid Loss: 0.0681 rmse_cov: 0.006348473933337122
# Epoch 96/1999
# ----------
# train Loss: 0.0529 rmse_cov: 0.004042060784438335
# valid Loss: 0.0685 rmse_cov: 0.006295992582817386
# Epoch 97/1999
# ----------
# train Loss: 0.0526 rmse_cov: 0.004066347580090029
# valid Loss: 0.0677 rmse_cov: 0.0058566403158517
# Epoch 98/1999
# ----------
# train Loss: 0.0523 rmse_cov: 0.00393528717095097
# valid Loss: 0.0681 rmse_cov: 0.005842635290068942
# Epoch 99/1999
# ----------
# train Loss: 0.0521 rmse_cov: 0.004344440908786261
# valid Loss: 0.0684 rmse_cov: 0.006175766633235719
# Epoch 100/1999
# ----------
# train Loss: 0.0516 rmse_cov: 0.004003994130781947
# valid Loss: 0.0682 rmse_cov: 0.007782954554275637
# Epoch 101/1999
# ----------
# train Loss: 0.0517 rmse_cov: 0.003892235247378516
# valid Loss: 0.0680 rmse_cov: 0.00554932494492257
# Epoch 102/1999
# ----------
# train Loss: 0.0512 rmse_cov: 0.0038161185912139596
# valid Loss: 0.0675 rmse_cov: 0.00568462344234181
# Epoch 103/1999
# ----------
# train Loss: 0.0511 rmse_cov: 0.00388309513011766
# valid Loss: 0.0677 rmse_cov: 0.005813253404232683
# Epoch 104/1999
# ----------
# train Loss: 0.0509 rmse_cov: 0.003755162234784334
# valid Loss: 0.0670 rmse_cov: 0.005446392869098258
# Epoch 105/1999
# ----------
# train Loss: 0.0507 rmse_cov: 0.004243428334838858
# valid Loss: 0.0669 rmse_cov: 0.006052251711466144
# Epoch 106/1999
# ----------
# train Loss: 0.0503 rmse_cov: 0.003663700424764091
# valid Loss: 0.0664 rmse_cov: 0.0059789650113218976
# Epoch 107/1999
# ----------
# train Loss: 0.0499 rmse_cov: 0.0037083736602462045
# valid Loss: 0.0675 rmse_cov: 0.006244828643393183
# Epoch 108/1999
# ----------
# train Loss: 0.0495 rmse_cov: 0.0034837861050705517
# valid Loss: 0.0664 rmse_cov: 0.006447412979565328
# Epoch 109/1999
# ----------
# train Loss: 0.0495 rmse_cov: 0.0035258000524660948
# valid Loss: 0.0675 rmse_cov: 0.0058495355536398765
# Epoch 110/1999
# ----------
# train Loss: 0.0492 rmse_cov: 0.0036212333984156956
# valid Loss: 0.0669 rmse_cov: 0.0059526720806933
# Epoch 111/1999
# ----------
# train Loss: 0.0490 rmse_cov: 0.0034717957574394165
# valid Loss: 0.0664 rmse_cov: 0.0058072070878394996
# Epoch 112/1999
# ----------
# train Loss: 0.0488 rmse_cov: 0.0035017602662546624
# valid Loss: 0.0665 rmse_cov: 0.005808197379297455
# Epoch 113/1999
# ----------
# train Loss: 0.0485 rmse_cov: 0.0034045025228491275
# valid Loss: 0.0667 rmse_cov: 0.005941142885865054
# Epoch 114/1999
# ----------
# train Loss: 0.0485 rmse_cov: 0.0034802797718191856
# valid Loss: 0.0673 rmse_cov: 0.00574907018595391
# Epoch 115/1999
# ----------
# train Loss: 0.0481 rmse_cov: 0.003536487264210005
# valid Loss: 0.0665 rmse_cov: 0.005906564127664928
# Epoch 116/1999
# ----------
# train Loss: 0.0477 rmse_cov: 0.003499110059314634
# valid Loss: 0.0661 rmse_cov: 0.006151972167902571
# Epoch 117/1999
# ----------
# train Loss: 0.0482 rmse_cov: 0.0035205966065954067
# valid Loss: 0.0668 rmse_cov: 0.005677850394065836
# Epoch 118/1999
# ----------
# train Loss: 0.0481 rmse_cov: 0.003458568954409323
# valid Loss: 0.0670 rmse_cov: 0.005537091560224273
# Epoch 119/1999
# ----------
# train Loss: 0.0485 rmse_cov: 0.0037385442498456337
# valid Loss: 0.0715 rmse_cov: 0.0077063153185539255
# Epoch 120/1999
# ----------
# train Loss: 0.0502 rmse_cov: 0.0038763006538468994
# valid Loss: 0.0672 rmse_cov: 0.006182044575777737
# Epoch 121/1999
# ----------
# train Loss: 0.0512 rmse_cov: 0.0042618494958301415
# valid Loss: 0.0665 rmse_cov: 0.006448753098060298
# Epoch 122/1999
# ----------
# train Loss: 0.0476 rmse_cov: 0.003324350709377214
# valid Loss: 0.0650 rmse_cov: 0.0056480050813955684
# Epoch 123/1999
# ----------
# train Loss: 0.0464 rmse_cov: 0.0031195813825223577
# valid Loss: 0.0660 rmse_cov: 0.0049430390811727965
# Epoch 124/1999
# ----------
# train Loss: 0.0462 rmse_cov: 0.0031774511470393737
# valid Loss: 0.0654 rmse_cov: 0.005894884960720358
# Epoch 125/1999
# ----------
# train Loss: 0.0458 rmse_cov: 0.003174775166475411
# valid Loss: 0.0647 rmse_cov: 0.005658907486842826
# Epoch 126/1999
# ----------
# train Loss: 0.0455 rmse_cov: 0.002919089683720448
# valid Loss: 0.0646 rmse_cov: 0.005442681521120176
# Epoch 127/1999
# ----------
# train Loss: 0.0453 rmse_cov: 0.0030328320631111834
# valid Loss: 0.0656 rmse_cov: 0.00532127439804668
# Epoch 129/1999
# ----------
# train Loss: 0.0449 rmse_cov: 0.002877171202958122
# valid Loss: 0.0639 rmse_cov: 0.005304112229632099
# Epoch 130/1999
# ----------
# train Loss: 0.0447 rmse_cov: 0.0028885175556530797
# valid Loss: 0.0639 rmse_cov: 0.004752120215625422
# Epoch 131/1999
# ----------
# train Loss: 0.0447 rmse_cov: 0.0029916166633498407
# valid Loss: 0.0641 rmse_cov: 0.005674070881121803
# Epoch 132/1999
# ----------
# train Loss: 0.0447 rmse_cov: 0.0032182710371320084
# valid Loss: 0.0643 rmse_cov: 0.005589804594424681
# Epoch 133/1999
# ----------
# train Loss: 0.0447 rmse_cov: 0.0031469456889401184
# valid Loss: 0.0650 rmse_cov: 0.005866148087023318
# Epoch 134/1999
# ----------
# train Loss: 0.0445 rmse_cov: 0.0030439071904760605
# valid Loss: 0.0643 rmse_cov: 0.005356012084475605
# Epoch 135/1999
# ----------
# train Loss: 0.0442 rmse_cov: 0.0029813991839613197
# valid Loss: 0.0635 rmse_cov: 0.0053056067951804346
# Epoch 136/1999
# ----------
# train Loss: 0.0443 rmse_cov: 0.0032289294706210826
# valid Loss: 0.0640 rmse_cov: 0.00507884180984546
# Epoch 137/1999
# ----------
# train Loss: 0.0438 rmse_cov: 0.0029466009653201595
# valid Loss: 0.0642 rmse_cov: 0.004943007253036657
# Epoch 138/1999
# ----------
# train Loss: 0.0437 rmse_cov: 0.002868444750520383
# valid Loss: 0.0634 rmse_cov: 0.005034083018138179
# Epoch 139/1999
# ----------
# train Loss: 0.0436 rmse_cov: 0.00285184193075826
# valid Loss: 0.0644 rmse_cov: 0.005821948067442328
# Epoch 140/1999
# ----------
# train Loss: 0.0434 rmse_cov: 0.0029609687830406575
# valid Loss: 0.0640 rmse_cov: 0.0049061662877651156
# Epoch 141/1999
# ----------
# train Loss: 0.0434 rmse_cov: 0.002899410848932613
# valid Loss: 0.0642 rmse_cov: 0.005481480350748401
# Epoch 142/1999
# ----------
# train Loss: 0.0434 rmse_cov: 0.00283008261844784
# valid Loss: 0.0633 rmse_cov: 0.005467534383335247
# Epoch 143/1999
# ----------
# train Loss: 0.0430 rmse_cov: 0.0028840187143269916
# valid Loss: 0.0638 rmse_cov: 0.0057532130812671025
# Epoch 144/1999
# ----------
# train Loss: 0.0428 rmse_cov: 0.0028039229620001145
# valid Loss: 0.0641 rmse_cov: 0.004940154473567628
# Epoch 145/1999
# ----------
# train Loss: 0.0425 rmse_cov: 0.0026831830561100003
# valid Loss: 0.0638 rmse_cov: 0.005284987665015797
# Epoch 146/1999
# ----------
# train Loss: 0.0422 rmse_cov: 0.0027272941404421812
# valid Loss: 0.0631 rmse_cov: 0.005154826868190723
# Epoch 147/1999
# ----------
# train Loss: 0.0424 rmse_cov: 0.0027086956818059066
# valid Loss: 0.0637 rmse_cov: 0.005032583953669651
# Epoch 148/1999
# ----------
# train Loss: 0.0422 rmse_cov: 0.002634871632660496
# valid Loss: 0.0634 rmse_cov: 0.0048792328914679
# Epoch 149/1999
# ----------
# train Loss: 0.0421 rmse_cov: 0.0027202496369500657
# valid Loss: 0.0639 rmse_cov: 0.004980606866288452
# Epoch 150/1999
# ----------
# train Loss: 0.0419 rmse_cov: 0.0026601221258201763
# valid Loss: 0.0634 rmse_cov: 0.004875607850461484
# Epoch 151/1999
# ----------
# train Loss: 0.0416 rmse_cov: 0.002564256929835469
# valid Loss: 0.0630 rmse_cov: 0.004565126272725248
# Epoch 152/1999
# ----------
# train Loss: 0.0417 rmse_cov: 0.0026810359146308186
# valid Loss: 0.0632 rmse_cov: 0.004922460819683009
# Epoch 153/1999
# ----------
# train Loss: 0.0416 rmse_cov: 0.002669613797295295
# valid Loss: 0.0630 rmse_cov: 0.005378625456861493
# Epoch 154/1999
# ----------
# train Loss: 0.0413 rmse_cov: 0.002693253553177895
# valid Loss: 0.0632 rmse_cov: 0.005191894986614891
# Epoch 155/1999
# ----------
# train Loss: 0.0412 rmse_cov: 0.002533716621474375
# valid Loss: 0.0627 rmse_cov: 0.005287045515127132
# Epoch 156/1999
# ----------
# train Loss: 0.0410 rmse_cov: 0.002626787645979521
# valid Loss: 0.0632 rmse_cov: 0.004949612261358139
# Epoch 157/1999
# ----------
# train Loss: 0.0415 rmse_cov: 0.002739410254250668
# valid Loss: 0.0678 rmse_cov: 0.008205948697583848
# Epoch 158/1999
# ----------
# train Loss: 0.0428 rmse_cov: 0.003461354025204915
# valid Loss: 0.0618 rmse_cov: 0.00490162367782777
# Epoch 159/1999
# ----------
# train Loss: 0.0411 rmse_cov: 0.002634950431238105
# valid Loss: 0.0625 rmse_cov: 0.005628121899436449
# Epoch 160/1999
# ----------
# train Loss: 0.0408 rmse_cov: 0.0026608297579145835
# valid Loss: 0.0626 rmse_cov: 0.005033156297001328
# Epoch 161/1999
# ----------
# train Loss: 0.0405 rmse_cov: 0.002596180683430543
# valid Loss: 0.0622 rmse_cov: 0.004942480327553734
# Epoch 162/1999
# ----------
# train Loss: 0.0402 rmse_cov: 0.0025501345927515387
# valid Loss: 0.0631 rmse_cov: 0.00524935957826796
# Epoch 163/1999
# ----------
# train Loss: 0.0401 rmse_cov: 0.002509563189804972
# valid Loss: 0.0626 rmse_cov: 0.004599205278144081
# Epoch 164/1999
# ----------
# train Loss: 0.0405 rmse_cov: 0.0025955533561742537
# valid Loss: 0.0623 rmse_cov: 0.005098634162345465
# Epoch 165/1999
# ----------
# train Loss: 0.0411 rmse_cov: 0.0026808434679652005
# valid Loss: 0.0622 rmse_cov: 0.00529886547037425
# Epoch 166/1999
# ----------
# train Loss: 0.0405 rmse_cov: 0.0025736864670313888
# valid Loss: 0.0627 rmse_cov: 0.005820308126779243
# Epoch 167/1999
# ----------
# train Loss: 0.0402 rmse_cov: 0.0025644811935773234
# valid Loss: 0.0611 rmse_cov: 0.004616049403781096
# Epoch 168/1999
# ----------
# train Loss: 0.0396 rmse_cov: 0.0023906309956563555
# valid Loss: 0.0616 rmse_cov: 0.004888490845132359
# Epoch 169/1999
# ----------
# train Loss: 0.0394 rmse_cov: 0.0025078963819898615
# valid Loss: 0.0621 rmse_cov: 0.00452690885982294
# Epoch 170/1999
# ----------
# train Loss: 0.0392 rmse_cov: 0.0024076596204984043
# valid Loss: 0.0621 rmse_cov: 0.004694015058281522
# Epoch 171/1999
# ----------
# train Loss: 0.0390 rmse_cov: 0.002410928068663823
# valid Loss: 0.0629 rmse_cov: 0.006020253250734722
# Epoch 172/1999
# ----------
# train Loss: 0.0389 rmse_cov: 0.002466100631589246
# valid Loss: 0.0616 rmse_cov: 0.005302022641910621
# Epoch 173/1999
# ----------
# train Loss: 0.0387 rmse_cov: 0.0022801843458183607
# valid Loss: 0.0620 rmse_cov: 0.005362730754631421
# Epoch 174/1999
# ----------
# train Loss: 0.0394 rmse_cov: 0.0025279797978242334
# valid Loss: 0.0617 rmse_cov: 0.005394888185874076
# Epoch 175/1999
# ----------
# train Loss: 0.0390 rmse_cov: 0.002495975752541233
# valid Loss: 0.0615 rmse_cov: 0.004774924336890179
# Epoch 176/1999
# ----------
# train Loss: 0.0387 rmse_cov: 0.0025585549474298926
# valid Loss: 0.0630 rmse_cov: 0.0058542872453565915
# Epoch 177/1999
# ----------
# train Loss: 0.0386 rmse_cov: 0.0023738054184128865
# valid Loss: 0.0615 rmse_cov: 0.004912548731825636
# Epoch 178/1999
# ----------
# train Loss: 0.0384 rmse_cov: 0.0023694444718736466
# valid Loss: 0.0617 rmse_cov: 0.004747336789625706
# Epoch 179/1999
# ----------
# train Loss: 0.0384 rmse_cov: 0.0023859003123209016
# valid Loss: 0.0609 rmse_cov: 0.004579758123239881
# Epoch 180/1999
# ----------
# train Loss: 0.0381 rmse_cov: 0.002271374538825231
# valid Loss: 0.0618 rmse_cov: 0.004584223593660885
# Epoch 181/1999
# ----------
# train Loss: 0.0382 rmse_cov: 0.002236236906226617
# valid Loss: 0.0617 rmse_cov: 0.004554401045436681
# Epoch 182/1999
# ----------
# train Loss: 0.0379 rmse_cov: 0.0022831148742638017
# valid Loss: 0.0607 rmse_cov: 0.0044430740931506365
# Epoch 183/1999
# ----------
# train Loss: 0.0378 rmse_cov: 0.0021966337469971047
# valid Loss: 0.0615 rmse_cov: 0.0050004673454229565
# Epoch 184/1999
# ----------
# train Loss: 0.0376 rmse_cov: 0.002262990546680741
# valid Loss: 0.0613 rmse_cov: 0.0051957652856265595
# Epoch 185/1999
# ----------
# train Loss: 0.0375 rmse_cov: 0.00238219548218866
# valid Loss: 0.0624 rmse_cov: 0.005787991672068342
# Epoch 186/1999
# ----------
# train Loss: 0.0377 rmse_cov: 0.0023254606678694404
# valid Loss: 0.0618 rmse_cov: 0.005026037994845393
# Epoch 187/1999
# ----------
# train Loss: 0.0375 rmse_cov: 0.00229011240189034
# valid Loss: 0.0615 rmse_cov: 0.004811778972349588
# Epoch 188/1999
# ----------
# train Loss: 0.0374 rmse_cov: 0.0023075789465201793
# valid Loss: 0.0604 rmse_cov: 0.0051541091232657895
# Epoch 189/1999
# ----------
# train Loss: 0.0373 rmse_cov: 0.002351659721915232
# valid Loss: 0.0612 rmse_cov: 0.004817598075840215
# Epoch 190/1999
# ----------
# train Loss: 0.0372 rmse_cov: 0.0023210891102528053
# valid Loss: 0.0628 rmse_cov: 0.004945969071830356
# Epoch 191/1999
# ----------
# train Loss: 0.0370 rmse_cov: 0.002201485656312359
# valid Loss: 0.0613 rmse_cov: 0.004743116675568598
# Epoch 192/1999
# ----------
# train Loss: 0.0369 rmse_cov: 0.0021850479856725825
# valid Loss: 0.0618 rmse_cov: 0.005031352894115626
# Epoch 193/1999
# ----------
# train Loss: 0.0368 rmse_cov: 0.002206005721671836
# valid Loss: 0.0613 rmse_cov: 0.005095654262612976
# Epoch 194/1999
# ----------
# train Loss: 0.0371 rmse_cov: 0.002354153862758054
# valid Loss: 0.0606 rmse_cov: 0.004970544863361383
# Epoch 195/1999
# ----------
# train Loss: 0.0370 rmse_cov: 0.0022721079464221713
# valid Loss: 0.0609 rmse_cov: 0.00494854476183085
# Epoch 196/1999
# ----------
# train Loss: 0.0365 rmse_cov: 0.0021973929116863096
# valid Loss: 0.0611 rmse_cov: 0.004764553463770214
# Epoch 197/1999
# ----------
# train Loss: 0.0366 rmse_cov: 0.002161508242256547
# valid Loss: 0.0613 rmse_cov: 0.004973343151587417
# Epoch 198/1999
# ----------
# train Loss: 0.0366 rmse_cov: 0.0022117607252738905
# valid Loss: 0.0610 rmse_cov: 0.004719463063625219
# Epoch 199/1999
# ----------
# train Loss: 0.0366 rmse_cov: 0.0022238283438061
# valid Loss: 0.0599 rmse_cov: 0.004616798962771129
# Epoch 200/1999
# ----------
# train Loss: 0.0363 rmse_cov: 0.0021490436134309174
# valid Loss: 0.0611 rmse_cov: 0.004764530780561874
# Epoch 201/1999
# ----------
# train Loss: 0.0363 rmse_cov: 0.002284669547765807
# valid Loss: 0.0613 rmse_cov: 0.004779498817315411
# Epoch 202/1999
# ----------
# train Loss: 0.0361 rmse_cov: 0.0021289238290511654
# valid Loss: 0.0607 rmse_cov: 0.004602353295221776
# Epoch 203/1999
# ----------
# train Loss: 0.0362 rmse_cov: 0.0021762912310606705
# valid Loss: 0.0616 rmse_cov: 0.004813023609000814
# Epoch 204/1999
# ----------
# train Loss: 0.0359 rmse_cov: 0.0020564529128211284
# valid Loss: 0.0615 rmse_cov: 0.005025956203291
# Epoch 205/1999
# ----------
# train Loss: 0.0359 rmse_cov: 0.002063248910005468
# valid Loss: 0.0612 rmse_cov: 0.004403752834672271
# Epoch 206/1999
# ----------
# train Loss: 0.0357 rmse_cov: 0.002053607236925751
# valid Loss: 0.0607 rmse_cov: 0.004488096384267259
# Epoch 207/1999
# ----------
# train Loss: 0.0356 rmse_cov: 0.0021921697578114545
# valid Loss: 0.0607 rmse_cov: 0.005041496639105847
# Epoch 208/1999
# ----------
# train Loss: 0.0355 rmse_cov: 0.0020259535195902008
# valid Loss: 0.0606 rmse_cov: 0.004462821048042002
# Epoch 209/1999
# ----------
# train Loss: 0.0355 rmse_cov: 0.002088469098736657
# valid Loss: 0.0607 rmse_cov: 0.0046776933328673605
# Epoch 210/1999
# ----------
# train Loss: 0.0354 rmse_cov: 0.0020504009113922186
# valid Loss: 0.0606 rmse_cov: 0.004359121261587093
# Epoch 211/1999
# ----------
# train Loss: 0.0353 rmse_cov: 0.002127403999048044
# valid Loss: 0.0603 rmse_cov: 0.004849142318297023
# Epoch 212/1999
# ----------
# train Loss: 0.0351 rmse_cov: 0.0019923462946330453
# valid Loss: 0.0594 rmse_cov: 0.004393109401086876
# Epoch 213/1999
# ----------
# train Loss: 0.0351 rmse_cov: 0.0020736527629254447
# valid Loss: 0.0606 rmse_cov: 0.004491571479705175
# Epoch 214/1999
# ----------
# train Loss: 0.0352 rmse_cov: 0.0022520851270460304
# valid Loss: 0.0608 rmse_cov: 0.004603866040448781
# Epoch 215/1999
# ----------
# train Loss: 0.0351 rmse_cov: 0.0021638705501750913
# valid Loss: 0.0607 rmse_cov: 0.004656192904197391
# Epoch 216/1999
# ----------
# train Loss: 0.0350 rmse_cov: 0.0020813745850662016
# valid Loss: 0.0612 rmse_cov: 0.0046430827667018944
# Epoch 217/1999
# ----------
# train Loss: 0.0350 rmse_cov: 0.0019642304288454136
# valid Loss: 0.0591 rmse_cov: 0.004297009476477984
# Epoch 218/1999
# ----------
# train Loss: 0.0347 rmse_cov: 0.0020909283742888496
# valid Loss: 0.0601 rmse_cov: 0.004466087219809121
# Epoch 219/1999
# ----------
# train Loss: 0.0347 rmse_cov: 0.002010499259346935
# valid Loss: 0.0605 rmse_cov: 0.005118785393719616
# Epoch 220/1999
# ----------
# train Loss: 0.0347 rmse_cov: 0.0022677242616989187
# valid Loss: 0.0601 rmse_cov: 0.004643482582803886
# Epoch 221/1999
# ----------
# train Loss: 0.0347 rmse_cov: 0.001958586041460784
# valid Loss: 0.0607 rmse_cov: 0.004625675346104561
# Epoch 222/1999
# ----------
# train Loss: 0.0344 rmse_cov: 0.0019260410215326909
# valid Loss: 0.0612 rmse_cov: 0.0048560335141575855
# Epoch 223/1999
# ----------
# train Loss: 0.0344 rmse_cov: 0.0019667094165346905
# valid Loss: 0.0602 rmse_cov: 0.005043990561188523
# Epoch 224/1999
# ----------
# train Loss: 0.0343 rmse_cov: 0.0020167149017590847
# valid Loss: 0.0606 rmse_cov: 0.004889131334784126
# Epoch 225/1999
# ----------
# train Loss: 0.0342 rmse_cov: 0.001933237055808818
# valid Loss: 0.0614 rmse_cov: 0.004392350775079625
# Epoch 226/1999
# ----------
# train Loss: 0.0345 rmse_cov: 0.002406007984247107
# valid Loss: 0.0608 rmse_cov: 0.004559625088699976
# Epoch 227/1999
# ----------
# train Loss: 0.0343 rmse_cov: 0.0020423684618146786
# valid Loss: 0.0592 rmse_cov: 0.004099249380775712
# Epoch 228/1999
# ----------
# train Loss: 0.0342 rmse_cov: 0.0019136339747656762
# valid Loss: 0.0602 rmse_cov: 0.004628132899541626
# Epoch 229/1999
# ----------
# train Loss: 0.0339 rmse_cov: 0.002035089088387671
# valid Loss: 0.0604 rmse_cov: 0.004684884356718536
# Epoch 230/1999
# ----------
# train Loss: 0.0340 rmse_cov: 0.001974952492729762
# valid Loss: 0.0609 rmse_cov: 0.004922170109379217
# Epoch 231/1999
# ----------
# train Loss: 0.0339 rmse_cov: 0.0019402876110190697
# valid Loss: 0.0603 rmse_cov: 0.00426710061019164
# Epoch 232/1999
# ----------
# train Loss: 0.0337 rmse_cov: 0.001913443062915268
# valid Loss: 0.0602 rmse_cov: 0.005144892085410697
# Epoch 233/1999
# ----------
# train Loss: 0.0338 rmse_cov: 0.001960975621937235
# valid Loss: 0.0608 rmse_cov: 0.004353451971064484
# Epoch 234/1999
# ----------
# train Loss: 0.0336 rmse_cov: 0.0018925762469644448
# valid Loss: 0.0610 rmse_cov: 0.004857169195979691
# Epoch 235/1999
# ----------
# train Loss: 0.0343 rmse_cov: 0.0019879762511670336
# valid Loss: 0.0593 rmse_cov: 0.004580026160801968
# Epoch 236/1999
# ----------
# train Loss: 0.0337 rmse_cov: 0.0018981206292090448
# valid Loss: 0.0597 rmse_cov: 0.004962131870471342
# Epoch 237/1999
# ----------
# train Loss: 0.0336 rmse_cov: 0.0018754127612725907
# valid Loss: 0.0600 rmse_cov: 0.004104827760601481
# Epoch 238/1999
# ----------
# train Loss: 0.0333 rmse_cov: 0.0021125513172346373
# valid Loss: 0.0593 rmse_cov: 0.0043845192367270875
# Epoch 239/1999
# ----------
# train Loss: 0.0333 rmse_cov: 0.0018581038044049758
# valid Loss: 0.0606 rmse_cov: 0.004704799355030167
# Epoch 240/1999
# ----------
# train Loss: 0.0332 rmse_cov: 0.0018697153310875973
# valid Loss: 0.0592 rmse_cov: 0.004293611529602077
# Epoch 241/1999
# ----------
# train Loss: 0.0332 rmse_cov: 0.0018271271031811858
# valid Loss: 0.0597 rmse_cov: 0.004358494353260769
# Epoch 242/1999
# ----------
# train Loss: 0.0331 rmse_cov: 0.0018169081137749592
# valid Loss: 0.0611 rmse_cov: 0.004774660871722676
# Epoch 243/1999
# ----------
# train Loss: 0.0330 rmse_cov: 0.001788284622040062
# valid Loss: 0.0612 rmse_cov: 0.004180640191556212
# Epoch 244/1999
# ----------
# train Loss: 0.0331 rmse_cov: 0.0018978054544360348
# valid Loss: 0.0591 rmse_cov: 0.00415965763355147
# Epoch 245/1999
# ----------
# train Loss: 0.0328 rmse_cov: 0.0018422904237029684
# valid Loss: 0.0602 rmse_cov: 0.0047104458525487405
# Epoch 246/1999
# ----------
# train Loss: 0.0333 rmse_cov: 0.001855647554899711
# valid Loss: 0.0605 rmse_cov: 0.005250858685989338
# Epoch 247/1999
# ----------
# train Loss: 0.0331 rmse_cov: 0.0019205421010030446
# valid Loss: 0.0593 rmse_cov: 0.0044031986393767535
# Epoch 248/1999
# ----------
# train Loss: 0.0328 rmse_cov: 0.001822910104649809
# valid Loss: 0.0590 rmse_cov: 0.003997044095405757
# Epoch 249/1999
# ----------
# train Loss: 0.0326 rmse_cov: 0.0018150109886212594
# valid Loss: 0.0591 rmse_cov: 0.004435374313548438
# Epoch 250/1999
# ----------
# train Loss: 0.0326 rmse_cov: 0.0017744107920153469
# valid Loss: 0.0593 rmse_cov: 0.004753324028171641
# Epoch 251/1999
# ----------
# train Loss: 0.0326 rmse_cov: 0.0018047935092327385
# valid Loss: 0.0597 rmse_cov: 0.004466768601841628
# Epoch 252/1999
# ----------
# train Loss: 0.0326 rmse_cov: 0.0018564658033994028
# valid Loss: 0.0587 rmse_cov: 0.004355895951563278
# Epoch 253/1999
# ----------
# train Loss: 0.0324 rmse_cov: 0.0017433037750236597
# valid Loss: 0.0603 rmse_cov: 0.00441849828692473
# Epoch 254/1999
# ----------
# train Loss: 0.0323 rmse_cov: 0.001841632802162621
# valid Loss: 0.0599 rmse_cov: 0.004141514255598977
# Epoch 255/1999
# ----------
# train Loss: 0.0324 rmse_cov: 0.0018599676017132943
# valid Loss: 0.0602 rmse_cov: 0.004538874200374181
# Epoch 256/1999
# ----------
# train Loss: 0.0321 rmse_cov: 0.00186332240230205
# valid Loss: 0.0602 rmse_cov: 0.004199746606195522
# Epoch 257/1999
# ----------
# train Loss: 0.0324 rmse_cov: 0.0017996112798810441
# valid Loss: 0.0593 rmse_cov: 0.004744411324574794
# Epoch 258/1999
# ----------
# train Loss: 0.0322 rmse_cov: 0.0017945078427197233
# valid Loss: 0.0594 rmse_cov: 0.004349658859050249
# Epoch 259/1999
# ----------
# train Loss: 0.0322 rmse_cov: 0.001690920809565469
# valid Loss: 0.0607 rmse_cov: 0.004356949832958612
# Epoch 260/1999
# ----------
# train Loss: 0.0322 rmse_cov: 0.0017700240699735738
# valid Loss: 0.0596 rmse_cov: 0.005090312039672033
# Epoch 261/1999
# ----------
# train Loss: 0.0322 rmse_cov: 0.001915000756452685
# valid Loss: 0.0596 rmse_cov: 0.004644418327566475
# Epoch 262/1999
# ----------
# train Loss: 0.0321 rmse_cov: 0.0017377336349353554
# valid Loss: 0.0596 rmse_cov: 0.0047007336483779775
# Epoch 263/1999
# ----------
# train Loss: 0.0320 rmse_cov: 0.0016533541915658028
# valid Loss: 0.0588 rmse_cov: 0.004438099876266881
# Epoch 264/1999
# ----------
# train Loss: 0.0318 rmse_cov: 0.001745461514054325
# valid Loss: 0.0601 rmse_cov: 0.004269785281638391
# Epoch 265/1999
# ----------
# train Loss: 0.0319 rmse_cov: 0.0017608733514040366
# valid Loss: 0.0592 rmse_cov: 0.0047171871782560265
# Epoch 266/1999
# ----------
# train Loss: 0.0318 rmse_cov: 0.0016614215000467366
# valid Loss: 0.0605 rmse_cov: 0.004532319165105801
# Epoch 267/1999
# ----------
# train Loss: 0.0316 rmse_cov: 0.0017293572011452293
# valid Loss: 0.0594 rmse_cov: 0.0045558592108008705
# Epoch 268/1999
# ----------
# train Loss: 0.0318 rmse_cov: 0.0017142226709013152
# valid Loss: 0.0592 rmse_cov: 0.004295115183031585
# Epoch 269/1999
# ----------
# train Loss: 0.0317 rmse_cov: 0.0017046022109591145
# valid Loss: 0.0608 rmse_cov: 0.004613223887678324
# Epoch 270/1999
# ----------
# train Loss: 0.0318 rmse_cov: 0.0018604570217839837
# valid Loss: 0.0596 rmse_cov: 0.004552347748034339
# Epoch 271/1999
# ----------
# train Loss: 0.0318 rmse_cov: 0.0017055477397867813
# valid Loss: 0.0587 rmse_cov: 0.0044480619218586395
# Epoch 272/1999
# ----------
# train Loss: 0.0315 rmse_cov: 0.0017787353769600227
# valid Loss: 0.0583 rmse_cov: 0.004111841622791047
# Epoch 273/1999
# ----------
# train Loss: 0.0316 rmse_cov: 0.0018799631340663174
# valid Loss: 0.0590 rmse_cov: 0.00428279551004214
# Epoch 274/1999
# ----------
# INFO: Early stopping after 274 epochs
# Training complete in 478m 57s
