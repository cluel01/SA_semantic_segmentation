# %% [markdown]
# # Imports

# %%
import sys 
sys.path.append("/home/jovyan/work/notebooks/satellite_data/SA_segmentation/")
import rasterio
from rasterio.plot import show
from rasterio.mask import mask
from rasterio.windows import from_bounds
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
import numpy as np
from patchify import patchify
import torch
from torch.nn import DataParallel
from torch.functional import F
from torch import nn
from torch.utils.data import DataLoader
from shapely.geometry import box
from torchvision import transforms
import time
import random

from pytorch_segmentation.data.train_dataset import TrainDataset
from pytorch_segmentation.data.inmemory_dataset import InMemorySatDataset
from pytorch_segmentation.train_net import train
from pytorch_segmentation.models import UNet
from pytorch_segmentation.losses.dice import DiceLoss
from pytorch_segmentation.losses.tversky import TverskyLoss
from pytorch_segmentation.losses.dice_V2 import FocalTversky_loss
from pytorch_segmentation.losses.bce_pixel_weights import CrossEntropyWithPixelWeights
import pytorch_segmentation.augmentation.transforms as seg_transforms

seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# %%
cfg = {
    #SA high resoluted data
    "shape_path_sa_high": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/data_pool/SA_tree_shapes/labels.geojson",
    "train_data_path_sa_high": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/train/SA_high",
    "val_data_path_sa_high": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/val/SA_high",
    "test_data_path_sa_high": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/test/SA_high",
    "tree_size_threshold_sa_high": 0.3,
    
    # #Rwanda data 2008
    "shape_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/data_pool/rwanda_tree_shapes/Training_Data_Rwanda_high_res.geojson",
    "train_data_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/train/rwanda_2008",
    "val_data_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/val/rwanda_2008",
    "test_data_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/test/rwanda_2008",
    "tree_size_threshold_rw_2008": 0.6,

    "tensorboard_path": "/home/jovyan/work/notebooks/runs",

    # patch_size = [364,364,3]# [x,y,bands]
    # overlap = 300

    # patch_size = [321,321,3]# [x,y,bands]
    # overlap = 270


    "patch_size": [300,300],# [x,y,bands]
    "overlap": 260,

    "val_patch_size": [256,256],# [x,y,bands]
    "val_overlap": 200,

    "test_patch_size": [256,256],
    "overlap_test": 128,

    "padding": False,#True

    "epochs": 500,#25

    "early_stopping": None,

    "dropout": True,

    "scheduler": False,
    "scheduler_warmup": 20,#10
    "sched_step": 15,
    "sched_gamma": 0.1,

    #batch_size = 200
    #batch_size = 50
    "batch_size": 50, #50 #150 #75

    "lr": 3e-4, #1e-3,
    "weight_decay": 1e-4, #1e-3,

    "weighted": True,
    "weight": 0.01,
    "sampler_replacement": True,

    "metric": "iou",

    "n_channels": 3,

    "nworkers": 4,
    "pin_memory": True,

    "nimgs": 7,
    "figsize": (24,21),
    
    "loss_fn": CrossEntropyWithPixelWeights(weights=[1,1.5])#nn.CrossEntropyLoss()#weight=torch.Tensor([0.25,4.]).to(torch.device("cuda:1"))) #TverskyLoss(0.3,0.7) 
}

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

save_dir = "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/saved_models"




transform_sa_high = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    seg_transforms.RandomApply([
        seg_transforms.Pad(100),
        seg_transforms.RandomRotation(360),
        seg_transforms.CenterCrop(282),
        seg_transforms.RandomResizeCrop((256,256),scale=(0.5,1)), #scale=(0.5,1)
        #seg_transforms.Add_VDVI(),
        seg_transforms.ColorJitter(brightness=(0.9,1.3),contrast=(0.9,1.3),saturation=0.2),
        
        #seg_transforms.ColorJitter(brightness=0.2,contrast=0.2,saturation=0.2),
        #seg_transforms.RandomPixel(ratio=0.005,random_apply=0.2)]
    ]
    ,p=1),
    seg_transforms.CenterCrop(256)
])



transform_rw_2008 = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    seg_transforms.RandomApply([
        seg_transforms.Pad(100),
        seg_transforms.RandomRotation(360),
        seg_transforms.CenterCrop(282),
        seg_transforms.RandomResizeCrop((256,256),scale=(0.5,1)), #scale=(0.5,1)
        #seg_transforms.Add_VDVI(),
        #seg_transforms.ColorJitter(brightness=(0.9,1.3),contrast=(0.9,1.3),saturation=0.2),
        #seg_transforms.ColorJitter(brightness=0.2,contrast=0.2,saturation=0.2),
        #seg_transforms.RandomPixel(ratio=0.005,random_apply=0.2)]
    ]
    ,p=1),
    seg_transforms.CenterCrop(256)
])





val_transform= None

val_transform_low = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    # seg_transforms.RandomHorizontalFlip(0.5),
    # seg_transforms.RandomVerticalFlip(0.5),
    #seg_transforms.UnmaskEdges([225,225])
#         seg_transforms.Normalize(mean=[0.5492, 0.5190, 0.4393],
#                                          std=[0.1381, 0.1320, 0.1349])
    seg_transforms.Resize(320),
    seg_transforms.CenterCrop(256),
])

test_transform = None

# %% [markdown]
# # 1.1 Data Collection

# %% [markdown]
# #### Create Training and Test Dataset - SA high

# %%
train_dataset_sa_high = TrainDataset(dataset_path=None,data_file_path=cfg["train_data_path_sa_high"],
                   shape_path=cfg["shape_path_sa_high"],tree_size_threshold=cfg["tree_size_threshold_sa_high"],
                             overlap=cfg["overlap"],patch_size=cfg["patch_size"],padding=cfg["padding"],transform=transform_sa_high)
val_dataset_sa_high = TrainDataset(dataset_path=None,data_file_path=cfg["val_data_path_sa_high"],
                   shape_path=cfg["shape_path_sa_high"],tree_size_threshold=cfg["tree_size_threshold_sa_high"],
                             overlap=cfg["val_overlap"],patch_size=cfg["val_patch_size"],padding=cfg["padding"],transform=val_transform)

# train_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_train,
#                              overlap=overlap,patch_size=patch_size,padding=padding,transform=transform)
# val_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_val,
#                              overlap=val_overlap,patch_size=val_patch_size,padding=padding,transform=val_transform)
# # test_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_test,
#                              overlap=overlap_test,patch_size=test_patch_size,padding=padding,transform=test_transform)


print("Len Train: ",len(train_dataset_sa_high))
print("Len Val: ",len(val_dataset_sa_high))
#print("Len Test: ",len(test_dataset_sa))
# Out:
#   0%|          | 0/127 [00:00<?, ?it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   1%|          | 1/127 [00:00<01:14,  1.70it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   2%|▏         | 2/127 [00:00<00:42,  2.96it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   2%|▏         | 3/127 [00:00<00:30,  4.01it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   3%|▎         | 4/127 [00:01<00:23,  5.16it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   4%|▍         | 5/127 [00:01<00:21,  5.58it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   5%|▍         | 6/127 [00:01<00:22,  5.39it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   6%|▌         | 7/127 [00:01<00:19,  6.05it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   6%|▋         | 8/127 [00:01<00:25,  4.72it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   7%|▋         | 9/127 [00:01<00:22,  5.33it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   8%|▊         | 10/127 [00:02<00:20,  5.81it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   9%|▉         | 12/127 [00:02<00:21,  5.44it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  13%|█▎        | 17/127 [00:03<00:26,  4.15it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  14%|█▍        | 18/127 [00:04<00:31,  3.42it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  15%|█▍        | 19/127 [00:04<00:38,  2.78it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  17%|█▋        | 21/127 [00:05<00:36,  2.91it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  17%|█▋        | 22/127 [00:05<00:35,  2.97it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  21%|██▏       | 27/127 [00:07<00:30,  3.32it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  25%|██▌       | 32/127 [00:08<00:26,  3.63it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  26%|██▌       | 33/127 [00:08<00:25,  3.62it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  31%|███▏      | 40/127 [00:10<00:28,  3.03it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  32%|███▏      | 41/127 [00:10<00:25,  3.36it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  33%|███▎      | 42/127 [00:11<00:23,  3.68it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  34%|███▍      | 43/127 [00:11<00:19,  4.22it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  35%|███▍      | 44/127 [00:11<00:21,  3.84it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  35%|███▌      | 45/127 [00:11<00:18,  4.43it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  36%|███▌      | 46/127 [00:12<00:34,  2.34it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  38%|███▊      | 48/127 [00:13<00:32,  2.43it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  39%|███▊      | 49/127 [00:13<00:28,  2.74it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  41%|████      | 52/127 [00:14<00:20,  3.71it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  43%|████▎     | 55/127 [00:15<00:26,  2.73it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  44%|████▍     | 56/127 [00:16<00:22,  3.09it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  46%|████▋     | 59/127 [00:17<00:28,  2.40it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  48%|████▊     | 61/127 [00:17<00:20,  3.16it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  51%|█████     | 65/127 [00:18<00:16,  3.80it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  53%|█████▎    | 67/127 [00:19<00:18,  3.23it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  54%|█████▎    | 68/127 [00:20<00:23,  2.51it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  55%|█████▌    | 70/127 [00:20<00:17,  3.24it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  56%|█████▌    | 71/127 [00:20<00:16,  3.35it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  57%|█████▋    | 73/127 [00:21<00:16,  3.29it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  58%|█████▊    | 74/127 [00:21<00:13,  3.79it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  62%|██████▏   | 79/127 [00:23<00:15,  3.11it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  64%|██████▍   | 81/127 [00:23<00:11,  3.93it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  65%|██████▌   | 83/127 [00:24<00:10,  4.13it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  66%|██████▌   | 84/127 [00:24<00:10,  4.13it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  68%|██████▊   | 86/127 [00:24<00:08,  5.12it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  69%|██████▊   | 87/127 [00:25<00:08,  4.66it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  71%|███████   | 90/127 [00:25<00:09,  4.08it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  72%|███████▏  | 91/127 [00:26<00:08,  4.45it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  72%|███████▏  | 92/127 [00:26<00:07,  4.67it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  73%|███████▎  | 93/127 [00:26<00:06,  5.00it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  74%|███████▍  | 94/127 [00:26<00:09,  3.42it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  76%|███████▌  | 96/127 [00:27<00:10,  3.01it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  76%|███████▋  | 97/127 [00:27<00:09,  3.07it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  77%|███████▋  | 98/127 [00:28<00:08,  3.59it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  80%|███████▉  | 101/127 [00:28<00:05,  4.52it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  82%|████████▏ | 104/127 [00:29<00:04,  4.97it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  83%|████████▎ | 106/127 [00:29<00:04,  5.20it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  84%|████████▍ | 107/127 [00:29<00:04,  4.31it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  85%|████████▌ | 108/127 [00:30<00:04,  4.55it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  87%|████████▋ | 110/127 [00:30<00:04,  4.09it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# ...
#   5%|▌         | 2/40 [00:00<00:05,  6.36it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  10%|█         | 4/40 [00:00<00:06,  5.36it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  12%|█▎        | 5/40 [00:01<00:07,  4.53it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  18%|█▊        | 7/40 [00:01<00:06,  5.05it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  20%|██        | 8/40 [00:01<00:06,  5.06it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  28%|██▊       | 11/40 [00:02<00:06,  4.29it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  32%|███▎      | 13/40 [00:02<00:05,  4.56it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  40%|████      | 16/40 [00:03<00:06,  3.61it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  42%|████▎     | 17/40 [00:04<00:07,  3.25it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  48%|████▊     | 19/40 [00:04<00:07,  2.97it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  50%|█████     | 20/40 [00:05<00:06,  3.03it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  52%|█████▎    | 21/40 [00:05<00:06,  2.96it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  60%|██████    | 24/40 [00:06<00:03,  4.48it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  70%|███████   | 28/40 [00:07<00:02,  4.38it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  72%|███████▎  | 29/40 [00:08<00:07,  1.53it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  75%|███████▌  | 30/40 [00:09<00:05,  1.69it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  80%|████████  | 32/40 [00:09<00:03,  2.43it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  82%|████████▎ | 33/40 [00:09<00:02,  2.77it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  92%|█████████▎| 37/40 [00:11<00:00,  3.00it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  98%|█████████▊| 39/40 [00:11<00:00,  3.40it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
# 100%|██████████| 40/40 [00:12<00:00,  3.32it/s]
# Len Train:  56181
# Len Val:  10741

# %%
train_dataset_sa_high.show_tuple(12349)

# %%
train_dataset_sa_high.show_tuple(12349,transform=False)

# %% [markdown]
# #### Create Training and Test Dataset - Rwanda 2008

# %%
train_dataset_rw_2008 = TrainDataset(dataset_path=None,data_file_path=cfg["train_data_path_rw_2008"],
                   shape_path=cfg["shape_path_rw_2008"],tree_size_threshold=cfg["tree_size_threshold_rw_2008"],
                             overlap=cfg["overlap"],patch_size=cfg["patch_size"],padding=cfg["padding"],transform=transform_rw_2008)
val_dataset_rw_2008 = TrainDataset(dataset_path=None,data_file_path=cfg["val_data_path_rw_2008"],
                   shape_path=cfg["shape_path_rw_2008"],tree_size_threshold=cfg["tree_size_threshold_rw_2008"],
                             overlap=cfg["val_overlap"],patch_size=cfg["val_patch_size"],padding=cfg["padding"],transform=val_transform)
# test_dataset_rw = RwandaDataset(dataset_path=None,data_file_path=test_data_path_rw,
#                    shape_path=shape_path_rw, overlap=overlap_test,patch_size=test_patch_size,padding=padding,transform=test_transform)

print("Len Train: ",len(train_dataset_rw_2008))
print("Len Val: ",len(val_dataset_rw_2008))
#print("Len Test: ",len(test_dataset_rw))
# Out:
#   0%|          | 0/67 [00:00<?, ?it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   1%|▏         | 1/67 [00:00<00:43,  1.51it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   3%|▎         | 2/67 [00:01<00:37,  1.71it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   6%|▌         | 4/67 [00:02<00:33,  1.90it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   7%|▋         | 5/67 [00:02<00:30,  2.04it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   9%|▉         | 6/67 [00:04<00:53,  1.13it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  10%|█         | 7/67 [00:04<00:44,  1.34it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  12%|█▏        | 8/67 [00:05<00:39,  1.51it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  13%|█▎        | 9/67 [00:05<00:37,  1.54it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  15%|█▍        | 10/67 [00:06<00:33,  1.69it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  16%|█▋        | 11/67 [00:07<00:49,  1.13it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  18%|█▊        | 12/67 [00:08<00:42,  1.30it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  19%|█▉        | 13/67 [00:08<00:36,  1.47it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  22%|██▏       | 15/67 [00:09<00:28,  1.84it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  24%|██▍       | 16/67 [00:10<00:26,  1.95it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  27%|██▋       | 18/67 [00:12<00:38,  1.27it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  28%|██▊       | 19/67 [00:12<00:32,  1.47it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  30%|██▉       | 20/67 [00:12<00:28,  1.65it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  31%|███▏      | 21/67 [00:13<00:27,  1.70it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  33%|███▎      | 22/67 [00:14<00:28,  1.58it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  34%|███▍      | 23/67 [00:14<00:26,  1.64it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  37%|███▋      | 25/67 [00:16<00:27,  1.50it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  40%|████      | 27/67 [00:17<00:22,  1.75it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  42%|████▏     | 28/67 [00:17<00:19,  1.96it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  43%|████▎     | 29/67 [00:18<00:20,  1.82it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  45%|████▍     | 30/67 [00:18<00:21,  1.75it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  46%|████▋     | 31/67 [00:19<00:19,  1.89it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  48%|████▊     | 32/67 [00:20<00:26,  1.30it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  51%|█████     | 34/67 [00:21<00:19,  1.73it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  52%|█████▏    | 35/67 [00:21<00:16,  1.90it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  54%|█████▎    | 36/67 [00:22<00:17,  1.78it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  55%|█████▌    | 37/67 [00:22<00:16,  1.81it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  57%|█████▋    | 38/67 [00:23<00:17,  1.64it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  60%|█████▉    | 40/67 [00:24<00:14,  1.86it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  61%|██████    | 41/67 [00:24<00:12,  2.01it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  63%|██████▎   | 42/67 [00:26<00:18,  1.34it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  64%|██████▍   | 43/67 [00:27<00:20,  1.18it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  67%|██████▋   | 45/67 [00:28<00:15,  1.44it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  72%|███████▏  | 48/67 [00:30<00:11,  1.66it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  75%|███████▍  | 50/67 [00:31<00:10,  1.70it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  76%|███████▌  | 51/67 [00:33<00:16,  1.03s/it]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  78%|███████▊  | 52/67 [00:33<00:12,  1.16it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  79%|███████▉  | 53/67 [00:35<00:14,  1.06s/it]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  82%|████████▏ | 55/67 [00:36<00:11,  1.08it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  84%|████████▎ | 56/67 [00:37<00:10,  1.05it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  85%|████████▌ | 57/67 [00:38<00:09,  1.10it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  87%|████████▋ | 58/67 [00:39<00:07,  1.27it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  88%|████████▊ | 59/67 [00:39<00:06,  1.26it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  90%|████████▉ | 60/67 [00:40<00:05,  1.30it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  91%|█████████ | 61/67 [00:41<00:03,  1.51it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  93%|█████████▎| 62/67 [00:41<00:03,  1.36it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  94%|█████████▍| 63/67 [00:42<00:03,  1.27it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  96%|█████████▌| 64/67 [00:43<00:02,  1.48it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  97%|█████████▋| 65/67 [00:44<00:01,  1.16it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
# 100%|██████████| 67/67 [00:45<00:00,  1.47it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   3%|▎         | 1/33 [00:00<00:20,  1.55it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   6%|▌         | 2/33 [00:01<00:15,  1.99it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   9%|▉         | 3/33 [00:01<00:17,  1.67it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  12%|█▏        | 4/33 [00:02<00:18,  1.53it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  15%|█▌        | 5/33 [00:02<00:15,  1.80it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  18%|█▊        | 6/33 [00:03<00:16,  1.63it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# ...
#  30%|███       | 10/33 [00:06<00:16,  1.39it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  33%|███▎      | 11/33 [00:06<00:14,  1.51it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  36%|███▋      | 12/33 [00:07<00:14,  1.42it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  39%|███▉      | 13/33 [00:08<00:13,  1.50it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  42%|████▏     | 14/33 [00:08<00:11,  1.64it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  45%|████▌     | 15/33 [00:09<00:10,  1.73it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  48%|████▊     | 16/33 [00:09<00:09,  1.72it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  55%|█████▍    | 18/33 [00:10<00:07,  1.93it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  58%|█████▊    | 19/33 [00:11<00:08,  1.61it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  61%|██████    | 20/33 [00:12<00:07,  1.72it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  64%|██████▎   | 21/33 [00:13<00:08,  1.37it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  67%|██████▋   | 22/33 [00:13<00:07,  1.54it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  70%|██████▉   | 23/33 [00:14<00:06,  1.66it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  73%|███████▎  | 24/33 [00:14<00:05,  1.56it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  79%|███████▉  | 26/33 [00:15<00:03,  1.78it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  82%|████████▏ | 27/33 [00:16<00:03,  1.51it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  85%|████████▍ | 28/33 [00:17<00:03,  1.63it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  91%|█████████ | 30/33 [00:18<00:01,  1.62it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  94%|█████████▍| 31/33 [00:19<00:01,  1.57it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  97%|█████████▋| 32/33 [00:20<00:00,  1.49it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
# 100%|██████████| 33/33 [00:20<00:00,  1.61it/s]
# Len Train:  41771
# Len Val:  6973

# %%
train_dataset_rw_2008.show_tuple(9)

# %%
train_dataset_rw_2008.show_tuple(9,transform=False)

# %% [markdown]
# # 2. Model Training

# %%
from pytorch_segmentation.utils.sampling import create_weighted_dataset
from pytorch_segmentation.data.concat_dataset import ConcatDataset

train_dataset,weights = create_weighted_dataset([train_dataset_sa_high,train_dataset_rw_2008,],weight=cfg["weight"])

sampler = torch.utils.data.sampler.WeightedRandomSampler(weights, len(weights),replacement=cfg["sampler_replacement"]) 

val_dataset = ConcatDataset([val_dataset_rw_2008, val_dataset_sa_high],shuffle=True)
#test_dataset = torch.utils.data.ConcatDataset([test_dataset_rw, test_dataset_sa])

# %%
if cfg["weighted"]:
    train_dl =DataLoader(train_dataset,sampler=sampler,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],shuffle=False,pin_memory=cfg["pin_memory"],
                      drop_last=True)
else:
    train_dl =DataLoader(train_dataset,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],shuffle=True,pin_memory=cfg["pin_memory"],
                  drop_last=True)

if (len(val_dataset) % cfg["batch_size"]) < cfg["nimgs"]:
    val_dl = DataLoader(val_dataset,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],
                     shuffle=False,pin_memory=cfg["pin_memory"],drop_last=True)
else:
    val_dl = DataLoader(val_dataset,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],
                         shuffle=False,pin_memory=cfg["pin_memory"],drop_last=False)
# test_dl = DataLoader(test_dataset,batch_size=batch_size,num_workers=nworkers,
#                      shuffle=False,pin_memory=pin_memory,drop_last=False)

# %% [markdown]
# ## 2.2 Advanced Unet
# https://github.com/milesial/Pytorch-UNet

# %%
model_path = save_dir+"/unet_"+str(time.strftime("%d_%m_%Y_%H%M%S"))
# Change here to adapt to your data
net = UNet(n_channels=3, n_classes=2, bilinear=False,dropout=cfg["dropout"])

net= DataParallel(net,device_ids=[0])

net = net.to(device=device)

# %%
opt = torch.optim.Adam(net.parameters(),lr=cfg["lr"])
#opt = torch.optim.Adam(net.parameters(),lr=lr,weight_decay=weight_decay)
if cfg["scheduler"]:
    scheduler = torch.optim.lr_scheduler.StepLR(opt, cfg["sched_step"],gamma=cfg["sched_gamma"]) #ReduceLROnPlateau(opt, 'max', patience=2) #S
else: 
    scheduler = None

# %%
train_loss,valid_loss = train(net,train_dl,val_dl,cfg["loss_fn"],opt,cfg["epochs"],model_path=model_path+".pth",scheduler=scheduler,
                              scheduler_warmup=cfg["scheduler_warmup"],early_stopping=cfg["early_stopping"],
                              metric=cfg["metric"],tensorboard_path=cfg["tensorboard_path"],nimgs=cfg["nimgs"],figsize=cfg["figsize"],cfg=cfg,device=device,seed=seed)
# Out:
# INFO: Start run for unet_02_03_2023_111113!
# Epoch 0/499
# ----------
# train Loss: 0.1897 iou: 0.7062929042757844
# valid Loss: 0.1999 iou: 0.7923290369754803
# Epoch 1/499
# ----------
# train Loss: 0.1416 iou: 0.7523537567813328
# valid Loss: 0.1871 iou: 0.7906317488864809
# Epoch 2/499
# ----------
# train Loss: 0.1259 iou: 0.767502156096915
# valid Loss: 0.1710 iou: 0.7970991304971381
# Epoch 3/499
# ----------
# train Loss: 0.1196 iou: 0.7763690482222617
# valid Loss: 0.1778 iou: 0.7983750066477786
# Epoch 4/499
# ----------
# train Loss: 0.1108 iou: 0.7896484983296945
# valid Loss: 0.1672 iou: 0.8104897701566639
# Epoch 5/499
# ----------
