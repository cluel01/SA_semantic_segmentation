# %% [markdown]
# # Imports

# %%
import sys 
sys.path.append("/home/jovyan/work/notebooks/satellite_data/SA_segmentation/")
import rasterio
from rasterio.plot import show
from rasterio.mask import mask
from rasterio.windows import from_bounds
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
import numpy as np
from patchify import patchify
import torch
from torch.nn import DataParallel
from torch.functional import F
from torch import nn
from torch.utils.data import DataLoader
from shapely.geometry import box
from torchvision import transforms
import time
import random

from pytorch_segmentation.data.train_dataset import TrainDataset
from pytorch_segmentation.data.inmemory_dataset import InMemorySatDataset
from pytorch_segmentation.train_net import train
from pytorch_segmentation.models import UNet
from pytorch_segmentation.losses.dice import DiceLoss
from pytorch_segmentation.losses.tversky import TverskyLoss
from pytorch_segmentation.losses.dice_V2 import FocalTversky_loss
import pytorch_segmentation.augmentation.transforms as seg_transforms
from pytorch_segmentation.losses.bce_pixel_weights import CrossEntropyWithPixelWeights

seed = 42
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# %%
cfg = {
    #SA high resoluted data
    "shape_path_sa_high": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/data_pool/SA_tree_shapes/labels.geojson",
    "train_data_path_sa_high": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/train/SA_high",
    "val_data_path_sa_high": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/val/SA_high",
    "test_data_path_sa_high": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/test/SA_high",
    "tree_size_threshold_sa_high": 0.3,
    
    #SA low data
    "shape_path_sa_low": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/data_pool/SA_tree_shapes/labels.geojson",
    "train_data_path_sa_low": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/train/SA_low",
    "val_data_path_sa_low": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/val/SA_low",
    "test_data_path_sa_low": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/test/SA_low",
    "tree_size_threshold_sa_low": 0.6,
    
    #Rwanda data 2008
    "shape_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/data_pool/rwanda_tree_shapes/Training_Data_Rwanda_high_res.geojson",
    "train_data_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/train/rwanda_2008",
    "val_data_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/val/rwanda_2008",
    "test_data_path_rw_2008": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/test/rwanda_2008",
    "tree_size_threshold_rw_2008": 0.6,
    
    #Rwanda data 2019
    "shape_path_rw_2019": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/data_pool/rwanda_tree_shapes/Training_Data_Rwanda_low_res.geojson",
    "train_data_path_rw_2019": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/train/rwanda_2019",
    "val_data_path_rw_2019": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/val/rwanda_2019",
    "test_data_path_rw_2019": "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/test/rwanda_2019",
    "tree_size_threshold_rw_2019": 0.6,

    "tensorboard_path": "/home/jovyan/work/notebooks/runs",

    # patch_size = [364,364,3]# [x,y,bands]
    # overlap = 300

    # patch_size = [321,321,3]# [x,y,bands]
    # overlap = 270


    "patch_size": [300,300],# [x,y,bands]
    "overlap": 260,

    "val_patch_size": [256,256],# [x,y,bands]
    "val_overlap": 200,

    "test_patch_size": [256,256],
    "overlap_test": 128,

    "padding": False,#True

    "epochs": 500,#25

    "early_stopping": None,

    "dropout": True,

    "scheduler": False,
    "scheduler_warmup": 20,#10
    "sched_step": 15,
    "sched_gamma": 0.1,

    #batch_size = 200
    #batch_size = 50
    "batch_size": 50, #50 #150 #75

    "lr": 3e-4, #1e-3,
    "weight_decay": 1e-4, #1e-3,

    "weighted": True,
    "weight": 0.25, #0.1
    "sampler_replacement": True,

    "metric": "iou",

    "n_channels": 3,

    "nworkers": 4,
    "pin_memory": True,

    "nimgs": 7,
    "figsize": (24,21),
    
    "loss_fn": CrossEntropyWithPixelWeights(weights=[1,1.3]),#nn.CrossEntropyLoss()#weight=torch.Tensor([0.25,4.]).to(torch.device("cuda:1"))) #TverskyLoss(0.3,0.7) 
}

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

save_dir = "/home/jovyan/work/notebooks/satellite_data/SA_segmentation/saved_models"




transform_sa_high = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    seg_transforms.RandomApply([
        seg_transforms.Pad(100),
        seg_transforms.RandomRotation(360),
        seg_transforms.CenterCrop(282),
        seg_transforms.RandomResizeCrop((256,256),scale=(0.5,1)), #scale=(0.5,1)
        #seg_transforms.Add_VDVI(),
        seg_transforms.ColorJitter(brightness=(0.9,1.3),contrast=(0.9,1.3),saturation=0.2),
        
        #seg_transforms.ColorJitter(brightness=0.2,contrast=0.2,saturation=0.2),
        #seg_transforms.RandomPixel(ratio=0.005,random_apply=0.2)]
    ]
    ,p=1),
    seg_transforms.CenterCrop(256)
])

transform_sa_low = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    seg_transforms.RandomApply([
        seg_transforms.Pad(100),
        seg_transforms.RandomRotation(360),
        seg_transforms.CenterCrop(282),
        seg_transforms.RandomResizeCrop((256,256),scale=(1.25,1.5)), #scale=(1,1)
        #seg_transforms.Add_VDVI(),
        #seg_transforms.ColorJitter(brightness=(0.9,1.3),contrast=(0.9,1.3),saturation=0.2),
        #seg_transforms.ColorJitter(brightness=0.2,contrast=0.2,saturation=0.2),
        #seg_transforms.RandomPixel(ratio=0.005,random_apply=0.2)]
    ],p=1),
    seg_transforms.CenterCrop(256)
])

transform_rw_2008 = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    seg_transforms.RandomApply([
        seg_transforms.Pad(100),
        seg_transforms.RandomRotation(360),
        seg_transforms.CenterCrop(282),
        seg_transforms.RandomResizeCrop((256,256),scale=(0.5,1)), #scale=(0.5,1)
        #seg_transforms.Add_VDVI(),
        #seg_transforms.ColorJitter(brightness=(0.9,1.3),contrast=(0.9,1.3),saturation=0.2),
        #seg_transforms.ColorJitter(brightness=0.2,contrast=0.2,saturation=0.2),
        #seg_transforms.RandomPixel(ratio=0.005,random_apply=0.2)]
    ]
    ,p=1),
    seg_transforms.CenterCrop(256)
])


transform_rw_2019 = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    seg_transforms.RandomApply([
        seg_transforms.Pad(100),
        seg_transforms.RandomRotation(360),
        seg_transforms.CenterCrop(282),
        seg_transforms.RandomResizeCrop((256,256),scale=(1.25,1.5)), #scale=(1,1)
        #seg_transforms.Add_VDVI(),
        #seg_transforms.ColorJitter(brightness=(0.9,1.3),contrast=(0.9,1.3),saturation=0.2),
        #seg_transforms.ColorJitter(brightness=0.2,contrast=0.2,saturation=0.2),
        #seg_transforms.RandomPixel(ratio=0.005,random_apply=0.2)]
    ]
    ,p=1),
    seg_transforms.CenterCrop(256)
])


val_transform= None

val_transform_low = seg_transforms.Compose([
    #seg_transforms.CLAHE_Norm(),
    # seg_transforms.RandomHorizontalFlip(0.5),
    # seg_transforms.RandomVerticalFlip(0.5),
    #seg_transforms.UnmaskEdges([225,225])
#         seg_transforms.Normalize(mean=[0.5492, 0.5190, 0.4393],
#                                          std=[0.1381, 0.1320, 0.1349])
    seg_transforms.Resize(320),
    seg_transforms.CenterCrop(256),
])

test_transform = None

# %% [markdown]
# # 1.1 Data Collection

# %% [markdown]
# #### Create Training and Test Dataset - SA high

# %%
train_dataset_sa_high = TrainDataset(dataset_path=None,data_file_path=cfg["train_data_path_sa_high"],
                   shape_path=cfg["shape_path_sa_high"],tree_size_threshold=cfg["tree_size_threshold_sa_high"],
                             overlap=cfg["overlap"],patch_size=cfg["patch_size"],padding=cfg["padding"],transform=transform_sa_high)
val_dataset_sa_high = TrainDataset(dataset_path=None,data_file_path=cfg["val_data_path_sa_high"],
                   shape_path=cfg["shape_path_sa_high"],
                             overlap=cfg["val_overlap"],patch_size=cfg["val_patch_size"],padding=cfg["padding"],transform=val_transform)

# train_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_train,
#                              overlap=overlap,patch_size=patch_size,padding=padding,transform=transform)
# val_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_val,
#                              overlap=val_overlap,patch_size=val_patch_size,padding=padding,transform=val_transform)
# # test_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_test,
#                              overlap=overlap_test,patch_size=test_patch_size,padding=padding,transform=test_transform)


print("Len Train: ",len(train_dataset_sa_high))
print("Len Val: ",len(val_dataset_sa_high))
#print("Len Test: ",len(test_dataset_sa))
# Out:
#   0%|          | 0/127 [00:00<?, ?it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   1%|          | 1/127 [00:00<01:09,  1.81it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   2%|▏         | 2/127 [00:00<00:39,  3.17it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   2%|▏         | 3/127 [00:00<00:28,  4.31it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   3%|▎         | 4/127 [00:00<00:22,  5.41it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   4%|▍         | 5/127 [00:01<00:20,  5.85it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   5%|▍         | 6/127 [00:01<00:21,  5.69it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   6%|▌         | 7/127 [00:01<00:19,  6.26it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   6%|▋         | 8/127 [00:01<00:25,  4.70it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   7%|▋         | 9/127 [00:01<00:21,  5.43it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   8%|▊         | 10/127 [00:01<00:19,  6.03it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   9%|▉         | 12/127 [00:02<00:19,  5.92it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  13%|█▎        | 17/127 [00:03<00:22,  4.91it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#
69it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  32%|███▎      | 13/40 [00:01<00:03,  7.52it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  40%|████      | 16/40 [00:02<00:04,  5.02it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  42%|████▎     | 17/40 [00:02<00:04,  5.07it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  48%|████▊     | 19/40 [00:02<00:03,  5.79it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  50%|█████     | 20/40 [00:02<00:03,  6.11it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  52%|█████▎    | 21/40 [00:03<00:03,  5.86it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  60%|██████    | 24/40 [00:03<00:02,  7.85it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  70%|███████   | 28/40 [00:03<00:01,  8.08it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  72%|███████▎  | 29/40 [00:04<00:03,  3.54it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  75%|███████▌  | 30/40 [00:04<00:02,  4.07it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  80%|████████  | 32/40 [00:05<00:01,  5.35it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  82%|████████▎ | 33/40 [00:05<00:01,  5.68it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  92%|█████████▎| 37/40 [00:05<00:00,  7.37it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  98%|█████████▊| 39/40 [00:05<00:00,  7.44it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
# 100%|██████████| 40/40 [00:06<00:00,  6.61it/s]
# Len Train:  56181
# Len Val:  10741

# %%
train_dataset_sa_high.show_tuple(9580)

# %%
train_dataset_sa_high.show_tuple(31500,transform=False)

# %% [markdown]
# #### Create Training and Test Dataset - SA low

# %%
train_dataset_sa_low = TrainDataset(dataset_path=None,data_file_path=cfg["train_data_path_sa_low"],
                   shape_path=cfg["shape_path_sa_low"],tree_size_threshold=cfg["tree_size_threshold_sa_low"],
                             overlap=cfg["overlap"],patch_size=cfg["patch_size"],padding=cfg["padding"],transform=transform_sa_low)
val_dataset_sa_low = TrainDataset(dataset_path=None,data_file_path=cfg["val_data_path_sa_low"],
                   shape_path=cfg["shape_path_sa_low"],
                             overlap=cfg["val_overlap"],patch_size=cfg["val_patch_size"],padding=cfg["padding"],transform=val_transform_low)

# train_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_train,
#                              overlap=overlap,patch_size=patch_size,padding=padding,transform=transform)
# val_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_val,
#                              overlap=val_overlap,patch_size=val_patch_size,padding=padding,transform=val_transform)
# # test_dataset_sa = InMemorySatDataset(data_file_path=data_path,mask_path=label_path_sa_test,
#                              overlap=overlap_test,patch_size=test_patch_size,padding=padding,transform=test_transform)


print("Len Train: ",len(train_dataset_sa_low))
print("Len Val: ",len(val_dataset_sa_low))
#print("Len Test: ",len(test_dataset_sa))
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   4%|▍         | 1/24 [00:00<00:03,  6.18it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  21%|██        | 5/24 [00:00<00:02,  6.46it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  25%|██▌       | 6/24 [00:00<00:03,  5.88it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  42%|████▏     | 10/24 [00:01<00:02,  6.50it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  54%|█████▍    | 13/24 [00:02<00:02,  4.84it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  58%|█████▊    | 14/24 [00:02<00:02,  4.70it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  79%|███████▉  | 19/24 [00:02<00:00,  6.10it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  83%|████████▎ | 20/24 [00:03<00:00,  5.20it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
# 100%|██████████| 24/24 [00:03<00:00,  6.37it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  23%|██▎       | 3/13 [00:00<00:01,  5.42it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  46%|████▌     | 6/13 [00:01<00:01,  3.69it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  54%|█████▍    | 7/13 [00:01<00:01,  3.44it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  69%|██████▉   | 9/13 [00:01<00:00,  4.75it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  92%|█████████▏| 12/13 [00:02<00:00,  6.34it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
# 100%|██████████| 13/13 [00:02<00:00,  5.47it/s]
# Len Train:  2294
# Len Val:  527

# %%
train_dataset_sa_low.show_tuple(130)

# %%
train_dataset_sa_low.show_tuple(130,transform=False)

# %% [markdown]
# #### Create Training and Test Dataset - Rwanda 2008

# %%
train_dataset_rw_2008 = TrainDataset(dataset_path=None,data_file_path=cfg["train_data_path_rw_2008"],
                   shape_path=cfg["shape_path_rw_2008"],tree_size_threshold=cfg["tree_size_threshold_rw_2008"],
                             overlap=cfg["overlap"],patch_size=cfg["patch_size"],padding=cfg["padding"],transform=transform_rw_2008)
val_dataset_rw_2008 = TrainDataset(dataset_path=None,data_file_path=cfg["val_data_path_rw_2008"],
                   shape_path=cfg["shape_path_rw_2008"],
                             overlap=cfg["val_overlap"],patch_size=cfg["val_patch_size"],padding=cfg["padding"],transform=val_transform)
# test_dataset_rw = RwandaDataset(dataset_path=None,data_file_path=test_data_path_rw,
#                    shape_path=shape_path_rw, overlap=overlap_test,patch_size=test_patch_size,padding=padding,transform=test_transform)

print("Len Train: ",len(train_dataset_rw_2008))
print("Len Val: ",len(val_dataset_rw_2008))
#print("Len Test: ",len(test_dataset_rw))
# Out:
#   0%|          | 0/67 [00:00<?, ?it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   1%|▏         | 1/67 [00:00<00:34,  1.94it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   3%|▎         | 2/67 [00:00<00:29,  2.20it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   6%|▌         | 4/67 [00:01<00:26,  2.39it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   7%|▋         | 5/67 [00:02<00:25,  2.46it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   9%|▉         | 6/67 [00:03<00:43,  1.40it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  10%|█         | 7/67 [00:03<00:36,  1.64it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  12%|█▏        | 8/67 [00:04<00:31,  1.87it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  13%|█▎        | 9/67 [00:04<00:29,  1.98it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  15%|█▍        | 10/67 [00:04<00:25,  2.20it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  16%|█▋        | 11/67 [00:06<00:36,  1.55it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  18%|█▊        | 12/67 [00:06<00:35,  1.53it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  19%|█▉        | 13/67 [00:07<00:30,  1.78it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  22%|██▏       | 15/67 [00:07<00:22,  2.32it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  24%|██▍       | 16/67 [00:08<00:21,  2.43it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  27%|██▋       | 18/67 [00:09<00:28,  1.70it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  28%|██▊       | 19/67 [00:09<00:24,  1.95it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  30%|██▉       | 20/67 [00:10<00:21,  2.19it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  31%|███▏      | 21/67 [00:10<00:21,  2.13it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  33%|███▎      | 22/67 [00:10<00:20,  2.24it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  34%|███▍      | 23/67 [00:11<00:21,  2.03it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  37%|███▋      | 25/67 [00:12<00:21,  1.96it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  40%|████      | 27/67 [00:13<00:17,  2.30it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  42%|████▏     | 28/67 [00:13<00:15,  2.56it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  43%|████▎     | 29/67 [00:14<00:15,  2.39it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  45%|████▍     | 30/67 [00:14<00:17,  2.13it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  46%|████▋     | 31/67 [00:14<00:15,  2.32it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  48%|████▊     | 32/67 [00:16<00:22,  1.58it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  51%|█████     | 34/67 [00:16<00:15,  2.12it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  52%|█████▏    | 35/67 [00:17<00:13,  2.31it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  54%|█████▎    | 36/67 [00:17<00:13,  2.30it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  55%|█████▌    | 37/67 [00:17<00:12,  2.38it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  57%|█████▋    | 38/67 [00:18<00:13,  2.13it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  60%|█████▉    | 40/67 [00:19<00:11,  2.35it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  61%|██████    | 41/67 [00:19<00:10,  2.50it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  63%|██████▎   | 42/67 [00:20<00:15,  1.60it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  64%|██████▍   | 43/67 [00:21<00:19,  1.21it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  67%|██████▋   | 45/67 [00:22<00:13,  1.61it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  72%|███████▏  | 48/67 [00:23<00:08,  2.23it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  75%|███████▍  | 50/67 [00:24<00:06,  2.45it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  76%|███████▌  | 51/67 [00:25<00:10,  1.47it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  78%|███████▊  | 52/67 [00:26<00:08,  1.74it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  79%|███████▉  | 53/67 [00:27<00:09,  1.40it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  82%|████████▏ | 55/67 [00:27<00:06,  1.80it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  84%|████████▎ | 56/67 [00:28<00:06,  1.77it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  85%|████████▌ | 57/67 [00:29<00:05,  1.78it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  87%|████████▋ | 58/67 [00:29<00:04,  2.09it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  88%|████████▊ | 59/67 [00:29<00:04,  1.98it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  90%|████████▉ | 60/67 [00:30<00:03,  2.07it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  91%|█████████ | 61/67 [00:30<00:02,  2.28it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  93%|█████████▎| 62/67 [00:31<00:02,  2.44it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  94%|█████████▍| 63/67 [00:31<00:01,  2.12it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  96%|█████████▌| 64/67 [00:32<00:01,  2.30it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  97%|█████████▋| 65/67 [00:32<00:01,  1.88it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
# 100%|██████████| 67/67 [00:33<00:00,  2.00it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   3%|▎         | 1/33 [00:00<00:15,  2.00it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   6%|▌         | 2/33 [00:00<00:12,  2.46it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   9%|▉         | 3/33 [00:01<00:12,  2.42it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  12%|█▏        | 4/33 [00:01<00:11,  2.58it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  15%|█▌        | 5/33 [00:01<00:09,  2.89it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  18%|█▊        | 6/33 [00:02<00:10,  2.66it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# ...
#  30%|███       | 10/33 [00:04<00:10,  2.17it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  33%|███▎      | 11/33 [00:04<00:09,  2.36it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  36%|███▋      | 12/33 [00:05<00:10,  2.07it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  39%|███▉      | 13/33 [00:05<00:09,  2.19it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  42%|████▏     | 14/33 [00:05<00:08,  2.32it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  45%|████▌     | 15/33 [00:06<00:07,  2.51it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  48%|████▊     | 16/33 [00:06<00:06,  2.55it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  55%|█████▍    | 18/33 [00:07<00:05,  2.95it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  58%|█████▊    | 19/33 [00:07<00:05,  2.39it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  61%|██████    | 20/33 [00:08<00:05,  2.47it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  64%|██████▎   | 21/33 [00:08<00:06,  1.92it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  67%|██████▋   | 22/33 [00:09<00:05,  2.16it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  70%|██████▉   | 23/33 [00:09<00:04,  2.25it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  73%|███████▎  | 24/33 [00:09<00:03,  2.35it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  79%|███████▉  | 26/33 [00:10<00:02,  2.74it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  82%|████████▏ | 27/33 [00:11<00:02,  2.38it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  85%|████████▍ | 28/33 [00:11<00:02,  2.43it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  91%|█████████ | 30/33 [00:12<00:01,  2.77it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  94%|█████████▍| 31/33 [00:12<00:00,  2.78it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  97%|█████████▋| 32/33 [00:12<00:00,  2.50it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
# 100%|██████████| 33/33 [00:13<00:00,  2.49it/s]
# Len Train:  41771
# Len Val:  6973

# %%
train_dataset_rw_2008.show_tuple(500)

# %%
train_dataset_rw_2008.show_tuple(500,transform=False)

# %% [markdown]
# #### Create Training and Test Dataset - Rwanda 2019

# %%
train_dataset_rw_2019 = TrainDataset(dataset_path=None,data_file_path=cfg["train_data_path_rw_2019"],
                   shape_path=cfg["shape_path_rw_2019"],tree_size_threshold=cfg["tree_size_threshold_rw_2019"],
                             overlap=cfg["overlap"],patch_size=cfg["patch_size"],padding=cfg["padding"],transform=transform_rw_2019)
val_dataset_rw_2019 = TrainDataset(dataset_path=None,data_file_path=cfg["val_data_path_rw_2019"],
                   shape_path=cfg["shape_path_rw_2019"],
                             overlap=cfg["val_overlap"],patch_size=cfg["val_patch_size"],padding=cfg["padding"],transform=val_transform_low)
# test_dataset_rw = RwandaDataset(dataset_path=None,data_file_path=test_data_path_rw,
#                    shape_path=shape_path_rw, overlap=overlap_test,patch_size=test_patch_size,padding=padding,transform=test_transform)

print("Len Train: ",len(train_dataset_rw_2019))
print("Len Val: ",len(val_dataset_rw_2019))
#print("Len Test: ",len(test_dataset_rw))
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#
/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  84%|████████▍ | 54/64 [00:29<00:05,  1.90it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  88%|████████▊ | 56/64 [00:30<00:03,  2.17it/s]
# Shape /home/jovyan/work/notebooks/satellite_data/SA_segmentation/data/datasets/V29/train/rwanda_2019/image_367_19.tif is too small for patch size with size: (3, 294, 468)
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  89%|████████▉ | 57/64 [00:31<00:04,  1.71it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  91%|█████████ | 58/64 [00:33<00:05,  1.02it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  92%|█████████▏| 59/64 [00:33<00:04,  1.25it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  95%|█████████▌| 61/64 [00:34<00:01,  1.50it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  97%|█████████▋| 62/64 [00:35<00:01,  1.73it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  98%|█████████▊| 63/64 [00:35<00:00,  1.71it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
# 100%|██████████| 64/64 [00:36<00:00,  1.76it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   4%|▍         | 1/26 [00:00<00:21,  1.18it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#   8%|▊         | 2/26 [00:01<00:14,  1.64it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# ...
#  23%|██▎       | 6/26 [00:03<00:12,  1.60it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  27%|██▋       | 7/26 [00:04<00:10,  1.78it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  31%|███       | 8/26 [00:04<00:09,  1.98it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  35%|███▍      | 9/26 [00:04<00:07,  2.22it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  38%|███▊      | 10/26 [00:05<00:07,  2.28it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  42%|████▏     | 11/26 [00:06<00:08,  1.83it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  46%|████▌     | 12/26 [00:07<00:10,  1.34it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  50%|█████     | 13/26 [00:07<00:08,  1.55it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  54%|█████▍    | 14/26 [00:08<00:07,  1.70it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  58%|█████▊    | 15/26 [00:08<00:05,  1.90it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  62%|██████▏   | 16/26 [00:09<00:05,  1.85it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  65%|██████▌   | 17/26 [00:10<00:06,  1.45it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  69%|██████▉   | 18/26 [00:10<00:05,  1.58it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  73%|███████▎  | 19/26 [00:10<00:03,  1.83it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  77%|███████▋  | 20/26 [00:11<00:02,  2.07it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  81%|████████  | 21/26 [00:12<00:02,  1.81it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  85%|████████▍ | 22/26 [00:12<00:02,  1.65it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  88%|████████▊ | 23/26 [00:13<00:02,  1.48it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  92%|█████████▏| 24/26 [00:14<00:01,  1.61it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
#  96%|█████████▌| 25/26 [00:14<00:00,  1.69it/s]/home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:194: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   big_trees= shape_df_filter[shape_df_filter.area*1000000000 > tree_size_threshold]
# /home/jovyan/work/notebooks/satellite_data/SA_segmentation/pytorch_segmentation/data/train_dataset.py:195: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   small_trees=shape_df_filter[shape_df_filter.area*1000000000 <= tree_size_threshold]
# 100%|██████████| 26/26 [00:15<00:00,  1.68it/s]
# Len Train:  29635
# Len Val:  4424

# %%
train_dataset_rw_2019.show_tuple(500)

# %%
train_dataset_rw_2019.show_tuple(500,transform=False)

# %% [markdown]
# # 2. Model Training

# %%
from pytorch_segmentation.utils.sampling import create_weighted_dataset
from pytorch_segmentation.data.concat_dataset import ConcatDataset

train_dataset,weights = create_weighted_dataset([train_dataset_sa_high,train_dataset_sa_low,train_dataset_rw_2008,train_dataset_rw_2019],weight=cfg["weight"])

sampler = torch.utils.data.sampler.WeightedRandomSampler(weights, len(weights),replacement=cfg["sampler_replacement"]) 

val_dataset = ConcatDataset([val_dataset_rw_2008,val_dataset_rw_2019, val_dataset_sa_high,val_dataset_sa_low],shuffle=True)
#test_dataset = torch.utils.data.ConcatDataset([test_dataset_rw, test_dataset_sa])

# %%
if cfg["weighted"]:
    train_dl =DataLoader(train_dataset,sampler=sampler,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],shuffle=False,pin_memory=cfg["pin_memory"],
                      drop_last=True)
else:
    train_dl =DataLoader(train_dataset,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],shuffle=True,pin_memory=cfg["pin_memory"],
                  drop_last=True)

if (len(val_dataset) % cfg["batch_size"]) < cfg["nimgs"]:
    val_dl = DataLoader(val_dataset,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],
                     shuffle=False,pin_memory=cfg["pin_memory"],drop_last=True)
else:
    val_dl = DataLoader(val_dataset,batch_size=cfg["batch_size"],num_workers=cfg["nworkers"],
                         shuffle=False,pin_memory=cfg["pin_memory"],drop_last=False)
# test_dl = DataLoader(test_dataset,batch_size=batch_size,num_workers=nworkers,
#                      shuffle=False,pin_memory=pin_memory,drop_last=False)

# %% [markdown]
# ## 2.2 Advanced Unet
# https://github.com/milesial/Pytorch-UNet

# %%
model_path = save_dir+"/unet_"+str(time.strftime("%d_%m_%Y_%H%M%S"))
# Change here to adapt to your data
net = UNet(n_channels=3, n_classes=2, bilinear=False,dropout=cfg["dropout"])

net= DataParallel(net,device_ids=[0])

net = net.to(device=device)

# %%
opt = torch.optim.Adam(net.parameters(),lr=cfg["lr"])
#opt = torch.optim.Adam(net.parameters(),lr=lr,weight_decay=weight_decay)
if cfg["scheduler"]:
    scheduler = torch.optim.lr_scheduler.StepLR(opt, cfg["sched_step"],gamma=cfg["sched_gamma"]) #ReduceLROnPlateau(opt, 'max', patience=2) #S
else: 
    scheduler = None

# %%
train_loss,valid_loss = train(net,train_dl,val_dl,cfg["loss_fn"],opt,cfg["epochs"],model_path=model_path+".pth",scheduler=scheduler,
                              scheduler_warmup=cfg["scheduler_warmup"],early_stopping=cfg["early_stopping"],
                              metric=cfg["metric"],tensorboard_path=cfg["tensorboard_path"],nimgs=cfg["nimgs"],figsize=cfg["figsize"],cfg=cfg,device=device,seed=seed)
# Out:
# INFO: Start run for unet_08_03_2023_082125!
# Epoch 0/499
# ----------
# train Loss: 0.3093 iou: 0.5180475292166683
# valid Loss: 0.2767 iou: 0.6940233425906813
# Epoch 1/499
# ----------
# train Loss: 0.2406 iou: 0.5889131368469055
# valid Loss: 0.2556 iou: 0.7229176357621893
# Epoch 2/499
# ----------
# train Loss: 0.2189 iou: 0.618401730103532
# valid Loss: 0.2541 iou: 0.7308063775846665
# Epoch 3/499
# ----------
# train Loss: 0.2055 iou: 0.6404114192790725
# valid Loss: 0.2437 iou: 0.7352527725283684
# Epoch 4/499
# ----------
# train Loss: 0.1943 iou: 0.6619580530319765
# valid Loss: 0.2471 iou: 0.7428990494408093
# Epoch 5/499
# ----------
# train Loss: 0.1864 iou: 0.6759317045086746
# valid Loss: 0.2539 iou: 0.7419938108738542
# Epoch 6/499
# ----------
# train Loss: 0.1814 iou: 0.684852348991848
# valid Loss: 0.2461 iou: 0.7494464480348331
# Epoch 7/499
# ----------
# train Loss: 0.1743 iou: 0.697554300579444
# valid Loss: 0.2627 iou: 0.7424610397843581
# Epoch 8/499
# ----------
# train Loss: 0.1700 iou: 0.7066864067216516
# valid Loss: 0.2488 iou: 0.7360639838280332
# Epoch 9/499
# ----------
